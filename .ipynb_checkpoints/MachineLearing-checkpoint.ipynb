# %%
# Dependencies
import json
import hvplot.pandas
import requests
from requests import post
from config import client_secret, client_id
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
import missingno as msno
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # joining twitchzaggle with additional and games data

# %%
# Read the usage_stats.csv file from the Resources folder into a Pandas DataFrame
twitch_zaggle_merged_df = pd.read_csv(
    Path("./Resources/TwitchZaggleMerged.csv")
)
additional_genre = pd.read_csv(
    Path("./Resources/Book1.csv")
)
games = pd.read_csv(
    Path("./Resources/games.csv")
)
# Out:
# C:\Users\nicoo\AppData\Local\Temp\ipykernel_15612\720886357.py:2: DtypeWarning: Columns (6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   twitch_zaggle_merged_df = pd.read_csv(

# %%
twitch_zaggle_merged_df.head()
# Out:
#                                                 game    year  \
# 0                                The Tiny Bang Story  2011.0
# 1                     World of Guns: Gun Disassembly  2014.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                            Hacknet  2015.0
# 4                                          SpaceChem  2011.0
#
#    metacritic_rating  reviewer_rating  positivity_ratio  rating_x  \
# 0               63.0              8.0          7.073879     84.85
# 1                NaN              8.0          5.208940     82.09
# 2               91.0              6.0          3.581082       NaN
# 3               82.0              8.0         14.548520     91.41
# 4               84.0              8.0         11.440415     88.72
#
#   primary_genre                                       store_genres  \
# 0     Adventure                   ['Adventure', 'Casual', 'Indie']
# 1          Free  ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# 2           NaN                                                NaN
# 3    Simulation                            ['Indie', 'Simulation']
# 4    Simulation                            ['Indie', 'Simulation']
#
#             publisher               developer  ... hypes  parent_game  \
# 0       Colibri Games           Colibri Games  ...   NaN          NaN
# 1  Noble Empire Corp.      Noble Empire Corp.  ...   NaN          NaN
# 2                 NaN                     NaN  ...   NaN          NaN
# 3    Fellow Traveller  Team Fractal Alligator  ...   NaN          NaN
# 4         Zachtronics             Zachtronics  ...   NaN          NaN
#
#     rating_y  rating_count total_rating total_rating_count aggregated_rating  \
# 0  72.926184          28.0    71.463092               29.0              70.0
# 1  66.706351           8.0    66.706351                8.0               NaN
# 2        NaN           NaN          NaN                NaN               NaN
# 3  77.907238          31.0    82.953619               32.0              88.0
# 4  83.151954          25.0    83.151954               25.0               NaN
#
#   aggregated_rating_count                                          storyline  \
# 0                     1.0                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     1.0  Bit, a hacker responsible for creating the mos...
# 4                     NaN                                                NaN
#
#   franchise
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 33 columns]

# %%
#length of the merged data
len(twitch_zaggle_merged_df)
# Out:
# 290213

# %%
additional_genre.head()
# Out:
#        id                              game  total_review review_score  \
# 0     730  Counter-Strike: Global Offensive       7382695          88%
# 1  578080               PUBG: BATTLEGROUNDS       2201296          57%
# 2     570                            Dota 2       2017009          82%
# 3  271590                Grand Theft Auto V       1322782       89.85%
# 4  359550   Tom Clancy's Rainbow Six® Siege        978762          86%
#
#   release_date launch_price                                              genre
# 0      8/21/12      $14.99   FPS, Shooter, Multiplayer, Competitive, Action...
# 1     12/21/17      $29.99   Survival, Shooter, Battle Royale, Multiplayer,...
# 2       7/9/13      $29.99   Free to Play, MOBA, Multiplayer, Strategy, eSp...
# 3      4/13/15      $29.99   Open World, Action, Multiplayer, Crime, Automo...
# 4      12/1/15      $59.99   FPS, PvP, eSports, Shooter, Multiplayer, Tacti...

# %%
# #Split the "list" into lists
# additional_genre['genre'] = additional_genre['genre'].str.split(',')
# additional_genre['genre'] = additional_genre['genre'].astype('object')  # Update the data type to 'object'

# print(additional_genre.dtypes)

# %%
# Keep the last occurrence of each duplicate based on the 'game' column
additional_genre = additional_genre.drop_duplicates(subset=['game'], keep='last')

# Now, 'additional_genre' has unique values in the 'game' column

# %%
# Check for duplicate values in the 'game' column of additional_genre
if additional_genre['game'].duplicated().any():
    print("Warning: Duplicate values found in the 'game' column of additional_genre. Please handle duplicates.")

# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['store_genres'] = twitch_zaggle_merged_df['store_genres'].fillna(
    twitch_zaggle_merged_df['game'].map(additional_genre.set_index('game')['genre'])
)

# %%
games.head()
# Out:
#                                       Name ReleaseDate  ReleaseYear  \
# 0               20th Century Video Almanac         NaN       1993.0
# 1                                 3D Atlas         NaN       1994.0
# 2                           3DO Action Pak         NaN       1995.0
# 3                    3DO Demo Disc Program         NaN          NaN
# 4  3DO Magazine: Interactive Sampler No 02         NaN          NaN
#
#                 Developer                     Platform      Genres  \
# 0  The Software Toolworks  3DO Interactive Multiplayer   Education
# 1         Electronic Arts  3DO Interactive Multiplayer   Education
# 2         The 3DO Company  3DO Interactive Multiplayer      Action
# 3                     NaN  3DO Interactive Multiplayer         NaN
# 4  Crystal Dynamics, Inc.  3DO Interactive Multiplayer         NaN
#
#                 Publisher  MaxPlayers          ESRB  \
# 0  The Software Toolworks         1.0     Not Rated
# 1         Electronic Arts         1.0  E - Everyone
# 2         The 3DO Company         1.0     Not Rated
# 3                     NaN         NaN           NaN
# 4  Crystal Dynamics, Inc.         1.0           NaN
#
#                                             Overview  Cooperative
# 0  In The Best of Our Century, we've taken multim...        False
# 1  3D Atlas for 3DO is an extremely data and art ...        False
# 2  This is a four-game compilation pack that cont...        False
# 3  A white binder with blue silk-screened art. Th...        False
# 4  Has trailers of Gex, and a game called Cybercl...        False

# %%
# Keep the last occurrence of each duplicate based on the 'game' column
games = games.drop_duplicates(subset=['Name'], keep='last')

# Now, 'additional_genre' has unique values in the 'game' column

# %%
# Check for duplicate values in the 'game' column of games
if games['Name'].duplicated().any():
    print("Warning: Duplicate values found in the 'Name' column of games. Please handle duplicates.")

# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and games
twitch_zaggle_merged_df['storyline'] = twitch_zaggle_merged_df['storyline'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Overview'])
)

# %%
twitch_zaggle_merged_df.head()
# Out:
#                                                 game    year  \
# 0                                The Tiny Bang Story  2011.0
# 1                     World of Guns: Gun Disassembly  2014.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                            Hacknet  2015.0
# 4                                          SpaceChem  2011.0
#
#    metacritic_rating  reviewer_rating  positivity_ratio  rating_x  \
# 0               63.0              8.0          7.073879     84.85
# 1                NaN              8.0          5.208940     82.09
# 2               91.0              6.0          3.581082       NaN
# 3               82.0              8.0         14.548520     91.41
# 4               84.0              8.0         11.440415     88.72
#
#   primary_genre                                       store_genres  \
# 0     Adventure                   ['Adventure', 'Casual', 'Indie']
# 1          Free  ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# 2           NaN  Simulation, Flight, Realistic, Open World, Mul...
# 3    Simulation                            ['Indie', 'Simulation']
# 4    Simulation                            ['Indie', 'Simulation']
#
#             publisher               developer  ... hypes  parent_game  \
# 0       Colibri Games           Colibri Games  ...   NaN          NaN
# 1  Noble Empire Corp.      Noble Empire Corp.  ...   NaN          NaN
# 2                 NaN                     NaN  ...   NaN          NaN
# 3    Fellow Traveller  Team Fractal Alligator  ...   NaN          NaN
# 4         Zachtronics             Zachtronics  ...   NaN          NaN
#
#     rating_y  rating_count total_rating total_rating_count aggregated_rating  \
# 0  72.926184          28.0    71.463092               29.0              70.0
# 1  66.706351           8.0    66.706351                8.0               NaN
# 2        NaN           NaN          NaN                NaN               NaN
# 3  77.907238          31.0    82.953619               32.0              88.0
# 4  83.151954          25.0    83.151954               25.0               NaN
#
#   aggregated_rating_count                                          storyline  \
# 0                     1.0  Life on Tiny Planet was calm and carefree unti...
# 1                     NaN  World of Guns: Gun Disassembly lets you delve ...
# 2                     NaN                                                NaN
# 3                     1.0  Bit, a hacker responsible for creating the mos...
# 4                     NaN  SpaceChem is a puzzle game about chemical engi...
#
#   franchise
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 33 columns]

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['store_genres'] = twitch_zaggle_merged_df['store_genres'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Genres'])
)

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['year'] = twitch_zaggle_merged_df['year'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['ReleaseYear'])
)

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['publisher'] = twitch_zaggle_merged_df['publisher'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Publisher'])
)

# %%
len(twitch_zaggle_merged_df)
# Out:
# 290213

# %%
twitch_zaggle_merged_df['themes']
# Out:
# 0         [17, 35]
# 1          [1, 34]
# 2              NaN
# 3             [43]
# 4             [18]
#             ...
# 290208     [1, 18]
# 290209        [18]
# 290210         NaN
# 290211         [1]
# 290212     [1, 18]
# Name: themes, Length: 290213, dtype: object

# %%
msno.bar(twitch_zaggle_merged_df)
# Out:
# <Axes: >

# %% [markdown]
# # Dropping NaN Values

# %%
columns_to_drop = ['year', 'age_ratings', 'metacritic_rating', 'rating_x', 'store_genres','publisher','tags_list','primary_genre','release_dates','summary','follows','collections','hypes','parent_game','rating_count', 'total_rating', 'total_rating_count','aggregated_rating','platforms', 'aggregated_rating_count', 'storyline','keywords',
                 'franchise']

# Drop the specified columns
dropped_df = twitch_zaggle_merged_df.drop(columns=columns_to_drop, axis=1)

# %%
df_filtered = dropped_df.dropna(thresh=dropped_df.shape[1] - 15)
df_filtered
# Out:
#                                                      game  reviewer_rating  \
# 0                                     The Tiny Bang Story              8.0
# 1                          World of Guns: Gun Disassembly              8.0
# 2       Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                                 Hacknet              8.0
# 4                                               SpaceChem              8.0
# ...                                                   ...              ...
# 290208                                  Enemy Infestation              NaN
# 290209                                 Sunsoft Collection              NaN
# 290210                                          Free D.C!              NaN
# 290211                      Flip the Gun - Simulator Game              NaN
# 290212                                Bomb Rush Cyberfunk              NaN
#
#         positivity_ratio               developer        id  \
# 0               7.073879           Colibri Games   15120.0
# 1               5.208940      Noble Empire Corp.    7555.0
# 2               3.581082                     NaN       NaN
# 3              14.548520  Team Fractal Alligator   11707.0
# 4              11.440415             Zachtronics    8390.0
# ...                  ...                     ...       ...
# 290208               NaN                     NaN   52526.0
# 290209               NaN                     NaN   79526.0
# 290210               NaN                     NaN   80526.0
# 290211               NaN                     NaN   95526.0
# 290212               NaN                     NaN  135940.0
#
#         first_release_date game_modes               genres    themes  \
# 0             1.303430e+09        [1]    [2, 7, 9, 31, 32]  [17, 35]
# 1             1.400630e+09        [1]       [5, 9, 13, 32]   [1, 34]
# 2                      NaN        NaN                  NaN       NaN
# 3             1.439338e+09        [1]          [9, 13, 32]      [43]
# 4             1.293840e+09        [1]      [9, 13, 15, 32]      [18]
# ...                    ...        ...                  ...       ...
# 290208        9.071136e+08  [1, 2, 3]             [11, 15]   [1, 18]
# 290209                 NaN        NaN                  [4]      [18]
# 290210        6.941376e+08        NaN                 [31]       NaN
# 290211        1.521590e+09        NaN                 [33]       [1]
# 290212        1.692317e+09        [1]  [8, 12, 14, 31, 32]   [1, 18]
#
#          rating_y
# 0       72.926184
# 1       66.706351
# 2             NaN
# 3       77.907238
# 4       83.151954
# ...           ...
# 290208        NaN
# 290209        NaN
# 290210        NaN
# 290211  90.000000
# 290212  70.055182
#
# [290213 rows x 10 columns]

# %%
msno.bar(dropped_df)
# Out:
# <Axes: >

# %% [markdown]
# # cleaning df_filtered

# %%
# Round the 'positivity_ratio' column to two decimal places
df_filtered['positivity_ratio'] = df_filtered['positivity_ratio'].round(2)
# fill.na(0)

# Display the modified DataFrame
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0        1.303430e+09
# 1              5.21      Noble Empire Corp.   7555.0        1.400630e+09
# 2              3.58                     NaN      NaN                 NaN
# 3             14.55  Team Fractal Alligator  11707.0        1.439338e+09
# 4             11.44             Zachtronics   8390.0        1.293840e+09
#
#   game_modes             genres    themes   rating_y
# 0        [1]  [2, 7, 9, 31, 32]  [17, 35]  72.926184
# 1        [1]     [5, 9, 13, 32]   [1, 34]  66.706351
# 2        NaN                NaN       NaN        NaN
# 3        [1]        [9, 13, 32]      [43]  77.907238
# 4        [1]    [9, 13, 15, 32]      [18]  83.151954

# %%
# Round the 'rating_y' column to two decimal places
df_filtered['rating_y'] = df_filtered['rating_y'].round(2)

# Display the modified DataFrame
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0        1.303430e+09
# 1              5.21      Noble Empire Corp.   7555.0        1.400630e+09
# 2              3.58                     NaN      NaN                 NaN
# 3             14.55  Team Fractal Alligator  11707.0        1.439338e+09
# 4             11.44             Zachtronics   8390.0        1.293840e+09
#
#   game_modes             genres    themes  rating_y
# 0        [1]  [2, 7, 9, 31, 32]  [17, 35]     72.93
# 1        [1]     [5, 9, 13, 32]   [1, 34]     66.71
# 2        NaN                NaN       NaN       NaN
# 3        [1]        [9, 13, 32]      [43]     77.91
# 4        [1]    [9, 13, 15, 32]      [18]     83.15

# %%
# # Extract the first number from each list in the 'genres' column
# df_filtered['genres'] = df_filtered['genres'].str[1]

# # Display the modified DataFrame
# df_filtered.head()

df_filtered['genres'] = df_filtered['genres'].str.extract(r'\[(\d+)')[0]

# Display the modified DataFrame
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0        1.303430e+09
# 1              5.21      Noble Empire Corp.   7555.0        1.400630e+09
# 2              3.58                     NaN      NaN                 NaN
# 3             14.55  Team Fractal Alligator  11707.0        1.439338e+09
# 4             11.44             Zachtronics   8390.0        1.293840e+09
#
#   game_modes genres    themes  rating_y
# 0        [1]      2  [17, 35]     72.93
# 1        [1]      5   [1, 34]     66.71
# 2        NaN    NaN       NaN       NaN
# 3        [1]      9      [43]     77.91
# 4        [1]      9      [18]     83.15

# %%
# # Convert Unix timestamp to datetime and extract year, month, and day
# df_filtered['release_date'] = pd.to_datetime(df_filtered['first_release_date'], unit='s')
# df_filtered['release_year'] = df_filtered['release_date'].dt.year
# df_filtered['release_month'] = df_filtered['release_date'].dt.month
# df_filtered['release_day'] = df_filtered['release_date'].dt.day

# # Display the modified DataFrame with extracted date components
# df_filtered.head()


#shows the year
df_filtered['first_release_date'] = pd.to_datetime(df_filtered['first_release_date'], unit='s').dt.year
df_filtered['first_release_date'] = df_filtered['first_release_date'].fillna(0).astype(int)
# Display the modified DataFrame with the extracted release year
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0                2011
# 1              5.21      Noble Empire Corp.   7555.0                2014
# 2              3.58                     NaN      NaN                   0
# 3             14.55  Team Fractal Alligator  11707.0                2015
# 4             11.44             Zachtronics   8390.0                2011
#
#   game_modes genres    themes  rating_y
# 0        [1]      2  [17, 35]     72.93
# 1        [1]      5   [1, 34]     66.71
# 2        NaN    NaN       NaN       NaN
# 3        [1]      9      [43]     77.91
# 4        [1]      9      [18]     83.15

# %%
### this code takes the first numbers in theme, remove if you want to keep the multiple numbers
df_filtered['themes'] = df_filtered['themes'].str.extract(r'\[(\d+)')[0]

# Display the modified DataFrame
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0                2011
# 1              5.21      Noble Empire Corp.   7555.0                2014
# 2              3.58                     NaN      NaN                   0
# 3             14.55  Team Fractal Alligator  11707.0                2015
# 4             11.44             Zachtronics   8390.0                2011
#
#   game_modes genres themes  rating_y
# 0        [1]      2     17     72.93
# 1        [1]      5      1     66.71
# 2        NaN    NaN    NaN       NaN
# 3        [1]      9     43     77.91
# 4        [1]      9     18     83.15

# %%
### this code takes the first numbers in game_modes, remove if you want to keep the multiple numbers
df_filtered['game_modes'] = df_filtered['game_modes'].str.extract(r'\[(\d+)')[0]

# Display the modified DataFrame
df_filtered.head()
# Out:
#                                                 game  reviewer_rating  \
# 0                                The Tiny Bang Story              8.0
# 1                     World of Guns: Gun Disassembly              8.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...              6.0
# 3                                            Hacknet              8.0
# 4                                          SpaceChem              8.0
#
#    positivity_ratio               developer       id  first_release_date  \
# 0              7.07           Colibri Games  15120.0                2011
# 1              5.21      Noble Empire Corp.   7555.0                2014
# 2              3.58                     NaN      NaN                   0
# 3             14.55  Team Fractal Alligator  11707.0                2015
# 4             11.44             Zachtronics   8390.0                2011
#
#   game_modes genres themes  rating_y
# 0          1      2     17     72.93
# 1          1      5      1     66.71
# 2        NaN    NaN    NaN       NaN
# 3          1      9     43     77.91
# 4          1      9     18     83.15

# %%
df_filtered.drop(columns = ['id'], inplace = True)

# %% [markdown]
# # saving df_filtered as csv

# %%
df_filtered.to_csv('Resources/df_filtered.csv', index=False)

# %% [markdown]
# # Numbering Genres

# %%
# nan_count = twitch_zaggle_merged_df['primary_genre'].isna().sum()

# print("Number of NaN values in 'primary_genre':", nan_count)

# %%
# # Load the genre API CSV containing genre mapping
# genre_api_df = pd.read_csv("./Resources/genre_api.csv")

# # Define a function to map genre names to numerical IDs
# def map_genres_to_ids(genre_list):
#     try:
#         # Convert the string to an actual list
#         genres = eval(genre_list)

#         # Map each genre name to its corresponding numerical ID
#         mapped_ids = [genre_api_df.loc[genre_api_df['name'] == genre, 'id'].values[0] for genre in genres]

#         return mapped_ids
#     except:
#         # If there's an issue (e.g., non-list format), return an empty list
#         return []

# # Apply the mapping function to the 'tags_list' column
# twitch_zaggle_merged_df['mapped_ids'] = twitch_zaggle_merged_df['tags_list'].apply(map_genres_to_ids)

# # Display the result
# print(twitch_zaggle_merged_df[['tags_list', 'mapped_ids']])

# %%
# (twitch_zaggle_merged_df[['tags_list', 'mapped_genres']])

# %% [markdown]
# # K-Means Clustering

# %%
df_filtered.set_index('game', inplace=True)
df_filtered
# Out:
#                                                     reviewer_rating  \
# game
# The Tiny Bang Story                                             8.0
# World of Guns: Gun Disassembly                                  8.0
# Microsoft Flight Simulator 40th Anniversary Edi...              6.0
# Hacknet                                                         8.0
# SpaceChem                                                       8.0
# ...                                                             ...
# Enemy Infestation                                               NaN
# Sunsoft Collection                                              NaN
# Free D.C!                                                       NaN
# Flip the Gun - Simulator Game                                   NaN
# Bomb Rush Cyberfunk                                             NaN
#
#                                                     positivity_ratio  \
# game
# The Tiny Bang Story                                             7.07
# World of Guns: Gun Disassembly                                  5.21
# Microsoft Flight Simulator 40th Anniversary Edi...              3.58
# Hacknet                                                        14.55
# SpaceChem                                                      11.44
# ...                                                              ...
# Enemy Infestation                                                NaN
# Sunsoft Collection                                               NaN
# Free D.C!                                                        NaN
# Flip the Gun - Simulator Game                                    NaN
# Bomb Rush Cyberfunk                                              NaN
#
#                                                                  developer  \
# game
# The Tiny Bang Story                                          Colibri Games
# World of Guns: Gun Disassembly                          Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                             Team Fractal Alligator
# SpaceChem                                                      Zachtronics
# ...                                                                    ...
# Enemy Infestation                                                      NaN
# Sunsoft Collection                                                     NaN
# Free D.C!                                                              NaN
# Flip the Gun - Simulator Game                                          NaN
# Bomb Rush Cyberfunk                                                    NaN
#
#                                                     first_release_date  \
# game
# The Tiny Bang Story                                               2011
# World of Guns: Gun Disassembly                                    2014
# Microsoft Flight Simulator 40th Anniversary Edi...                   0
# Hacknet                                                           2015
# SpaceChem                                                         2011
# ...                                                                ...
# Enemy Infestation                                                 1998
# Sunsoft Collection                                                   0
# Free D.C!                                                         1991
# Flip the Gun - Simulator Game                                     2018
# Bomb Rush Cyberfunk                                               2023
#
#                                                    game_modes genres themes  \
# game
# The Tiny Bang Story                                         1      2     17
# World of Guns: Gun Disassembly                              1      5      1
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN    NaN    NaN
# Hacknet                                                     1      9     43
# SpaceChem                                                   1      9     18
# ...                                                       ...    ...    ...
# Enemy Infestation                                           1     11      1
# Sunsoft Collection                                        NaN      4     18
# Free D.C!                                                 NaN     31    NaN
# Flip the Gun - Simulator Game                             NaN     33      1
# Bomb Rush Cyberfunk                                         1      8      1
#
#                                                     rating_y
# game
# The Tiny Bang Story                                    72.93
# World of Guns: Gun Disassembly                         66.71
# Microsoft Flight Simulator 40th Anniversary Edi...       NaN
# Hacknet                                                77.91
# SpaceChem                                              83.15
# ...                                                      ...
# Enemy Infestation                                        NaN
# Sunsoft Collection                                       NaN
# Free D.C!                                                NaN
# Flip the Gun - Simulator Game                          90.00
# Bomb Rush Cyberfunk                                    70.06
#
# [290213 rows x 8 columns]

# %%
# Generate summary statistics
# df_filtered.describe()

# %%
# df_filtered.shape

# %%
# Plot your data to see what's in your DataFrame
#twitch_zaggle_merged_df.hvplot.line(
#    width=800,
#    height=400,
#    rot=90
#)

# %% [markdown]
# # Prepare the Data

# %%
df_filtered.columns
# Out:
# Index(['reviewer_rating', 'positivity_ratio', 'developer',
#        'first_release_date', 'game_modes', 'genres', 'themes', 'rating_y'],
#       dtype='object')

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290213 entries, The Tiny Bang Story to Bomb Rush Cyberfunk
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   reviewer_rating     49825 non-null   float64
#  1   positivity_ratio    69746 non-null   float64
#  2   developer           76119 non-null   object
#  3   first_release_date  290213 non-null  int32
#  4   game_modes          142687 non-null  object
#  5   genres              214644 non-null  object
#  6   themes              143049 non-null  object
#  7   rating_y            30464 non-null   float64
# dtypes: float64(3), int32(1), object(4)
# memory usage: 18.8+ MB

# %%
import missingno as msno

msno.bar(df_filtered)
# Out:
# <Axes: >

# %%
# pip install missingno

# %%
msno.bar(df_filtered.drop(columns = 'rating_y').dropna(how = 'any'))
#cannot imput this because its over 20% of the data missing, so we are going about it this way
# Out:
# <Axes: >

# %%
df_dropped = df_filtered.drop(columns = 'rating_y').dropna(how = 'any')
df_dropped
# Out:
#                                 reviewer_rating  positivity_ratio  \
# game
# The Tiny Bang Story                         8.0              7.07
# World of Guns: Gun Disassembly              8.0              5.21
# Hacknet                                     8.0             14.55
# SpaceChem                                   8.0             11.44
# Learn to Fly 3                              8.0             15.57
# ...                                         ...               ...
# Omega Agent                                 6.0              3.15
# Time of Shadows                             4.0              0.58
# Drug Wars                                   4.0              0.42
# Uncharted Waters                            7.0              6.00
# Sangokushi Eiketsuden                       6.0              3.15
#
#                                                 developer  first_release_date  \
# game
# The Tiny Bang Story                         Colibri Games                2011
# World of Guns: Gun Disassembly         Noble Empire Corp.                2014
# Hacknet                            Team Fractal Alligator                2015
# SpaceChem                                     Zachtronics                2011
# Learn to Fly 3                   Light Bringer Games inc.                2017
# ...                                                   ...                 ...
# Omega Agent                               Fireproof Games                2016
# Time of Shadows                   SkyFallen Entertainment                2009
# Drug Wars                             Paleo Entertainment                2009
# Uncharted Waters                KOEI TECMO GAMES CO. LTD.                1990
# Sangokushi Eiketsuden           KOEI TECMO GAMES CO. LTD.                1995
#
#                                game_modes genres themes
# game
# The Tiny Bang Story                     1      2     17
# World of Guns: Gun Disassembly          1      5      1
# Hacknet                                 1      9     43
# SpaceChem                               1      9     18
# Learn to Fly 3                          1     13      1
# ...                                   ...    ...    ...
# Omega Agent                             1      5      1
# Time of Shadows                         1     12      1
# Drug Wars                               1      5      1
# Uncharted Waters                        1     12     17
# Sangokushi Eiketsuden                   1     12     17
#
# [18832 rows x 7 columns]

# %%
# Identify columns with missing values
# columns_with_missing_values = df_filtered.columns[df_filtered.isnull().any()].tolist()
# columns_with_missing_values
#not dropping these anymore due to the avoidance of imputing

# %%
# df_filtered.drop(columns = columns_with_missing_values, inplace = True)
# df_filtered

# %%
# for column in columns_with_missing_values:
#     print(f"Processing column: {column}")
    
#     if twitch_zaggle_merged_df[column].dtype == 'float64':
#         imputer = SimpleImputer(strategy='mean')
#     else:
#         imputer = SimpleImputer(strategy='most_frequent')
    
#     # Flatten lists and handle NaN values
#     flattened_values = twitch_zaggle_merged_df[column].apply(lambda x: x if isinstance(x, list) else [x])
#     flattened_values = flattened_values.apply(lambda x: x[0] if len(x) > 0 else np.nan)
    
#     imputed_values = imputer.fit_transform(flattened_values.values.reshape(-1, 1)).ravel()
    
#     print(f"Imputed values: {imputed_values}")
    
#     # Update the DataFrame using loc
#     twitch_zaggle_merged_df.loc[:, column] = imputed_values


# for column in columns_with_missing_values:
#     print(f"Processing column: {column}")
    
#     if df_filtered[column].dtype == 'float64':
#         imputed_values = df_filtered[column].fillna(df_filtered[column].mean())
#     else:
#         # For non-numeric columns, fill missing values with the most frequent value
#         most_frequent_value = df_filtered[column].mode().iloc[0]
#         imputed_values = df_filtered[column].fillna(most_frequent_value)
    
#     print(f"Imputed values: {imputed_values}")
    
#     # Update the DataFrame using loc
#     df_filtered.loc[:, column] = imputed_values

# %%
df_dropped.positivity_ratio.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_dropped.positivity_ratio.plot.box()
# Out:
# <Axes: >

# %%
# Generate summary statistics
df_dropped.describe(include='all')
# Out:
#         reviewer_rating  positivity_ratio  developer  first_release_date  \
# count      18832.000000      18832.000000      18832        18832.000000
# unique              NaN               NaN      12222                 NaN
# top                 NaN               NaN  RewindApp                 NaN
# freq                NaN               NaN         35                 NaN
# mean           6.488955          6.613152        NaN         1959.860875
# std            1.387789         10.244790        NaN          333.578755
# min            1.000000          0.040000        NaN            0.000000
# 25%            5.000000          1.790000        NaN         2015.000000
# 50%            7.000000          3.640000        NaN         2018.000000
# 75%            8.000000          7.652500        NaN         2020.000000
# max            9.000000        591.000000        NaN         2025.000000
#
#        game_modes genres themes
# count       18832  18832  18832
# unique          6     23     22
# top             1     12      1
# freq        17861   2871  13335
# mean          NaN    NaN    NaN
# std           NaN    NaN    NaN
# min           NaN    NaN    NaN
# 25%           NaN    NaN    NaN
# 50%           NaN    NaN    NaN
# 75%           NaN    NaN    NaN
# max           NaN    NaN    NaN

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18832 entries, The Tiny Bang Story to Sangokushi Eiketsuden
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reviewer_rating     18832 non-null  float64
#  1   positivity_ratio    18832 non-null  float64
#  2   developer           18832 non-null  object
#  3   first_release_date  18832 non-null  int32
#  4   game_modes          18832 non-null  object
#  5   genres              18832 non-null  object
#  6   themes              18832 non-null  object
# dtypes: float64(2), int32(1), object(4)
# memory usage: 1.1+ MB

# %%
df_dropped[['game_modes','genres','themes']] = df_dropped[['game_modes','genres','themes']].astype('int')
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18832 entries, The Tiny Bang Story to Sangokushi Eiketsuden
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reviewer_rating     18832 non-null  float64
#  1   positivity_ratio    18832 non-null  float64
#  2   developer           18832 non-null  object
#  3   first_release_date  18832 non-null  int32
#  4   game_modes          18832 non-null  int32
#  5   genres              18832 non-null  int32
#  6   themes              18832 non-null  int32
# dtypes: float64(2), int32(4), object(1)
# memory usage: 882.8+ KB

# %%
df_dropped.describe(include='all')
# Out:
#         reviewer_rating  positivity_ratio  developer  first_release_date  \
# count      18832.000000      18832.000000      18832        18832.000000
# unique              NaN               NaN      12222                 NaN
# top                 NaN               NaN  RewindApp                 NaN
# freq                NaN               NaN         35                 NaN
# mean           6.488955          6.613152        NaN         1959.860875
# std            1.387789         10.244790        NaN          333.578755
# min            1.000000          0.040000        NaN            0.000000
# 25%            5.000000          1.790000        NaN         2015.000000
# 50%            7.000000          3.640000        NaN         2018.000000
# 75%            8.000000          7.652500        NaN         2020.000000
# max            9.000000        591.000000        NaN         2025.000000
#
#           game_modes        genres        themes
# count   18832.000000  18832.000000  18832.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean        1.060217     14.695731      7.926349
# std         0.303075      9.933592     11.842565
# min         1.000000      2.000000      1.000000
# 25%         1.000000      8.000000      1.000000
# 50%         1.000000     12.000000      1.000000
# 75%         1.000000     15.000000     17.000000
# max         6.000000     36.000000     44.000000

# %%
df_dropped.shape
# Out:
# (18832, 7)

# %% [markdown]
# # Prepare the Data

# %%
df_dropped.head()
# Out:
#                                 reviewer_rating  positivity_ratio  \
# game
# The Tiny Bang Story                         8.0              7.07
# World of Guns: Gun Disassembly              8.0              5.21
# Hacknet                                     8.0             14.55
# SpaceChem                                   8.0             11.44
# Learn to Fly 3                              8.0             15.57
#
#                                                developer  first_release_date  \
# game
# The Tiny Bang Story                        Colibri Games                2011
# World of Guns: Gun Disassembly        Noble Empire Corp.                2014
# Hacknet                           Team Fractal Alligator                2015
# SpaceChem                                    Zachtronics                2011
# Learn to Fly 3                  Light Bringer Games inc.                2017
#
#                                 game_modes  genres  themes
# game
# The Tiny Bang Story                      1       2      17
# World of Guns: Gun Disassembly           1       5       1
# Hacknet                                  1       9      43
# SpaceChem                                1       9      18
# Learn to Fly 3                           1      13       1

# %%
# # Find rows with string representations of lists in the 'tags_list' column
# problematic_rows = twitch_zaggle_merged_df[twitch_zaggle_merged_df['tags_list'].apply(lambda x: isinstance(x, str) and '[' in x and ']' in x)]

# # Print the problematic rows
# print(problematic_rows[['tags_list']])

# %%
# Extract the second value from the "age_ratings" column and remove square brackets
# df_filtered['age_ratings'] = df_filtered['age_ratings'].str.extract('\[\d+, (\d+)').astype(float)

# # Print unique values in the column after conversion
# print("Unique values after conversion:", df_filtered['age_ratings'].unique())

#ended up removing because the api did not hook up to the other age rating api so it was not able to figure out what the 
#numbers mean

# %%
df_dropped.tail()
# Out:
#                        reviewer_rating  positivity_ratio  \
# game
# Omega Agent                        6.0              3.15
# Time of Shadows                    4.0              0.58
# Drug Wars                          4.0              0.42
# Uncharted Waters                   7.0              6.00
# Sangokushi Eiketsuden              6.0              3.15
#
#                                        developer  first_release_date  \
# game
# Omega Agent                      Fireproof Games                2016
# Time of Shadows          SkyFallen Entertainment                2009
# Drug Wars                    Paleo Entertainment                2009
# Uncharted Waters       KOEI TECMO GAMES CO. LTD.                1990
# Sangokushi Eiketsuden  KOEI TECMO GAMES CO. LTD.                1995
#
#                        game_modes  genres  themes
# game
# Omega Agent                     1       5       1
# Time of Shadows                 1      12       1
# Drug Wars                       1       5       1
# Uncharted Waters                1      12      17
# Sangokushi Eiketsuden           1      12      17

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18832 entries, The Tiny Bang Story to Sangokushi Eiketsuden
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reviewer_rating     18832 non-null  float64
#  1   positivity_ratio    18832 non-null  float64
#  2   developer           18832 non-null  object
#  3   first_release_date  18832 non-null  int32
#  4   game_modes          18832 non-null  int32
#  5   genres              18832 non-null  int32
#  6   themes              18832 non-null  int32
# dtypes: float64(2), int32(4), object(1)
# memory usage: 882.8+ KB

# %%
df_dropped.dtypes
# Out:
# reviewer_rating       float64
# positivity_ratio      float64
# developer              object
# first_release_date      int32
# game_modes              int32
# genres                  int32
# themes                  int32
# dtype: object

# %%
# List of columns to be one-hot encoded
columns_to_encode = ['developer', 'game_modes', 'genres', 'themes']

# Use pd.get_dummies to perform one-hot encoding
df_encoded = pd.get_dummies(df_dropped, columns=columns_to_encode)

# Display the first few rows of the encoded DataFrame
df_encoded.head()
# Out:
#                                 reviewer_rating  positivity_ratio  \
# game
# The Tiny Bang Story                         8.0              7.07
# World of Guns: Gun Disassembly              8.0              5.21
# Hacknet                                     8.0             14.55
# SpaceChem                                   8.0             11.44
# Learn to Fly 3                              8.0             15.57
#
#                                 first_release_date  developer_#workshop  \
# game
# The Tiny Bang Story                           2011                False
# World of Guns: Gun Disassembly                2014                False
# Hacknet                                       2015                False
# SpaceChem                                     2011                False
# Learn to Fly 3                                2017                False
#
#                                 developer_&quot;Nieko&quot;  \
# game
# The Tiny Bang Story                                   False
# World of Guns: Gun Disassembly                        False
# Hacknet                                               False
# SpaceChem                                             False
# Learn to Fly 3                                        False
#
#                                 developer_&quot;RevDay Studio&quot;  \
# game
# The Tiny Bang Story                                           False
# World of Guns: Gun Disassembly                                False
# Hacknet                                                       False
# SpaceChem                                                     False
# Learn to Fly 3                                                False
#
#                                 developer_+7 Software  \
# game
# The Tiny Bang Story                             False
# World of Guns: Gun Disassembly                  False
# Hacknet                                         False
# SpaceChem                                       False
# Learn to Fly 3                                  False
#
#                                 developer_+Mpact Games LLC.  developer_.Cat  \
# game
# The Tiny Bang Story                                   False           False
# World of Guns: Gun Disassembly                        False           False
# Hacknet                                               False           False
# SpaceChem                                             False           False
# Learn to Fly 3                                        False           False
#
#                                 developer_.ez Games  ...  themes_33  \
# game                                                 ...
# The Tiny Bang Story                           False  ...      False
# World of Guns: Gun Disassembly                False  ...      False
# Hacknet                                       False  ...      False
# SpaceChem                                     False  ...      False
# Learn to Fly 3                                False  ...      False
#
#                                 themes_34  themes_35  themes_38  themes_39  \
# game
# The Tiny Bang Story                 False      False      False      False
# World of Guns: Gun Disassembly      False      False      False      False
# Hacknet                             False      False      False      False
# SpaceChem                           False      False      False      False
# Learn to Fly 3                      False      False      False      False
#
#                                 themes_40  themes_41  themes_42  themes_43  \
# game
# The Tiny Bang Story                 False      False      False      False
# World of Guns: Gun Disassembly      False      False      False      False
# Hacknet                             False      False      False       True
# SpaceChem                           False      False      False      False
# Learn to Fly 3                      False      False      False      False
#
#                                 themes_44
# game
# The Tiny Bang Story                 False
# World of Guns: Gun Disassembly      False
# Hacknet                             False
# SpaceChem                           False
# Learn to Fly 3                      False
#
# [5 rows x 12276 columns]

# %%
df_dropped.developer.value_counts()
# Out:
# developer
# RewindApp                     35
# Ripknot Systems               31
# CAPCOM Co. Ltd.               29
# Kairosoft Co.Ltd              29
# Winged Cloud                  28
#                               ..
# WyvernWare                     1
# Garden Shed Studios            1
# Lead Money Games               1
# Draconus Entertainment Ltd     1
# Paleo Entertainment            1
# Name: count, Length: 12222, dtype: int64

# %%
#put the ones who show up only once then we want to bin these --in deep learning homework 
#check if there are typos or doubles
#distant base make sure to scale it
#user input through website, then use predict, take in all info to predict

# %%
print(df_dropped['developer'].isna().sum())
print(df_dropped['game_modes'].isna().sum())
# Out:
# 0
# 0

# %%
print(df_dropped['developer'].dtype)
print(df_dropped['game_modes'].dtype)
# Out:
# object
# int32

# %%
print(df_dropped['developer'].nunique())
print(df_dropped['game_modes'].nunique())
# Out:
# 12222
# 6

# %%
df_encoded = pd.get_dummies(df_dropped, columns=['game_modes'])

# %%
# df_filtered['age_ratings'] = df_filtered['age_ratings'].astype('category')
# df_encoded = pd.get_dummies(df_filtered, columns=['age_ratings'])
# doing age_ratings in this way created over 50k columns, so changing it to an alternative strategy
# label_encoder = LabelEncoder()
# df_encoded['age_ratings'] = label_encoder.fit_transform(df_filtered['age_ratings'])

# %%
# label_encoder = LabelEncoder()
# df_filtered['developer_encoded'] = label_encoder.fit_transform(df_filtered['developer'])

# %%
# print("Unique values before label encoding:", df_filtered['developer'].nunique())
# label_encoder = LabelEncoder()
# df_filtered['developer_encoded'] = label_encoder.fit_transform(df_filtered['developer'])
# print("Unique values after label encoding:", df_filtered['developer_encoded'].nunique())

# %%
# df_encoded.columns
#if encoding it will see it as heiracrhical

# %%
# print(df_filtered[['developer', 'developer_encoded']].head())

# %%
# # Perform label encoding on 'developer'
# label_encoder = LabelEncoder()
# df_filtered['developer_encoded'] = label_encoder.fit_transform(df_filtered['developer'])

# # List of columns to be one-hot encoded
# columns_to_encode = ['game_modes']

# # Use pd.get_dummies to perform one-hot encoding
# df_encoded = pd.get_dummies(df_filtered, columns=columns_to_encode)

# # Concatenate 'developer_encoded' column to df_encoded
# df_encoded = pd.concat([df_encoded, df_filtered['developer_encoded']], axis=1)

# # Display the first few rows of the concatenated DataFrame
# print(df_encoded.head())

# %%
df_encoded.columns
# Out:
# Index(['reviewer_rating', 'positivity_ratio', 'developer',
#        'first_release_date', 'genres', 'themes', 'game_modes_1',
#        'game_modes_2', 'game_modes_3', 'game_modes_4', 'game_modes_5',
#        'game_modes_6'],
#       dtype='object')

# %%
df_encoded
# Out:
#                                 reviewer_rating  positivity_ratio  \
# game
# The Tiny Bang Story                         8.0              7.07
# World of Guns: Gun Disassembly              8.0              5.21
# Hacknet                                     8.0             14.55
# SpaceChem                                   8.0             11.44
# Learn to Fly 3                              8.0             15.57
# ...                                         ...               ...
# Omega Agent                                 6.0              3.15
# Time of Shadows                             4.0              0.58
# Drug Wars                                   4.0              0.42
# Uncharted Waters                            7.0              6.00
# Sangokushi Eiketsuden                       6.0              3.15
#
#                                                 developer  first_release_date  \
# game
# The Tiny Bang Story                         Colibri Games                2011
# World of Guns: Gun Disassembly         Noble Empire Corp.                2014
# Hacknet                            Team Fractal Alligator                2015
# SpaceChem                                     Zachtronics                2011
# Learn to Fly 3                   Light Bringer Games inc.                2017
# ...                                                   ...                 ...
# Omega Agent                               Fireproof Games                2016
# Time of Shadows                   SkyFallen Entertainment                2009
# Drug Wars                             Paleo Entertainment                2009
# Uncharted Waters                KOEI TECMO GAMES CO. LTD.                1990
# Sangokushi Eiketsuden           KOEI TECMO GAMES CO. LTD.                1995
#
#                                 genres  themes  game_modes_1  game_modes_2  \
# game
# The Tiny Bang Story                  2      17          True         False
# World of Guns: Gun Disassembly       5       1          True         False
# Hacknet                              9      43          True         False
# SpaceChem                            9      18          True         False
# Learn to Fly 3                      13       1          True         False
# ...                                ...     ...           ...           ...
# Omega Agent                          5       1          True         False
# Time of Shadows                     12       1          True         False
# Drug Wars                            5       1          True         False
# Uncharted Waters                    12      17          True         False
# Sangokushi Eiketsuden               12      17          True         False
#
#                                 game_modes_3  game_modes_4  game_modes_5  \
# game
# The Tiny Bang Story                    False         False         False
# World of Guns: Gun Disassembly         False         False         False
# Hacknet                                False         False         False
# SpaceChem                              False         False         False
# Learn to Fly 3                         False         False         False
# ...                                      ...           ...           ...
# Omega Agent                            False         False         False
# Time of Shadows                        False         False         False
# Drug Wars                              False         False         False
# Uncharted Waters                       False         False         False
# Sangokushi Eiketsuden                  False         False         False
#
#                                 game_modes_6
# game
# The Tiny Bang Story                    False
# World of Guns: Gun Disassembly         False
# Hacknet                                False
# SpaceChem                              False
# Learn to Fly 3                         False
# ...                                      ...
# Omega Agent                            False
# Time of Shadows                        False
# Drug Wars                              False
# Uncharted Waters                       False
# Sangokushi Eiketsuden                  False
#
# [18832 rows x 12 columns]

# %%
df_filtered
# Out:
#                                                     reviewer_rating  \
# game
# The Tiny Bang Story                                             8.0
# World of Guns: Gun Disassembly                                  8.0
# Microsoft Flight Simulator 40th Anniversary Edi...              6.0
# Hacknet                                                         8.0
# SpaceChem                                                       8.0
# ...                                                             ...
# Enemy Infestation                                               NaN
# Sunsoft Collection                                              NaN
# Free D.C!                                                       NaN
# Flip the Gun - Simulator Game                                   NaN
# Bomb Rush Cyberfunk                                             NaN
#
#                                                     positivity_ratio  \
# game
# The Tiny Bang Story                                             7.07
# World of Guns: Gun Disassembly                                  5.21
# Microsoft Flight Simulator 40th Anniversary Edi...              3.58
# Hacknet                                                        14.55
# SpaceChem                                                      11.44
# ...                                                              ...
# Enemy Infestation                                                NaN
# Sunsoft Collection                                               NaN
# Free D.C!                                                        NaN
# Flip the Gun - Simulator Game                                    NaN
# Bomb Rush Cyberfunk                                              NaN
#
#                                                                  developer  \
# game
# The Tiny Bang Story                                          Colibri Games
# World of Guns: Gun Disassembly                          Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                             Team Fractal Alligator
# SpaceChem                                                      Zachtronics
# ...                                                                    ...
# Enemy Infestation                                                      NaN
# Sunsoft Collection                                                     NaN
# Free D.C!                                                              NaN
# Flip the Gun - Simulator Game                                          NaN
# Bomb Rush Cyberfunk                                                    NaN
#
#                                                     first_release_date  \
# game
# The Tiny Bang Story                                               2011
# World of Guns: Gun Disassembly                                    2014
# Microsoft Flight Simulator 40th Anniversary Edi...                   0
# Hacknet                                                           2015
# SpaceChem                                                         2011
# ...                                                                ...
# Enemy Infestation                                                 1998
# Sunsoft Collection                                                   0
# Free D.C!                                                         1991
# Flip the Gun - Simulator Game                                     2018
# Bomb Rush Cyberfunk                                               2023
#
#                                                    game_modes genres themes  \
# game
# The Tiny Bang Story                                         1      2     17
# World of Guns: Gun Disassembly                              1      5      1
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN    NaN    NaN
# Hacknet                                                     1      9     43
# SpaceChem                                                   1      9     18
# ...                                                       ...    ...    ...
# Enemy Infestation                                           1     11      1
# Sunsoft Collection                                        NaN      4     18
# Free D.C!                                                 NaN     31    NaN
# Flip the Gun - Simulator Game                             NaN     33      1
# Bomb Rush Cyberfunk                                         1      8      1
#
#                                                     rating_y
# game
# The Tiny Bang Story                                    72.93
# World of Guns: Gun Disassembly                         66.71
# Microsoft Flight Simulator 40th Anniversary Edi...       NaN
# Hacknet                                                77.91
# SpaceChem                                              83.15
# ...                                                      ...
# Enemy Infestation                                        NaN
# Sunsoft Collection                                       NaN
# Free D.C!                                                NaN
# Flip the Gun - Simulator Game                          90.00
# Bomb Rush Cyberfunk                                    70.06
#
# [290213 rows x 8 columns]
