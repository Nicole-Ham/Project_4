# %%
# Dependencies
import json
import hvplot.pandas
import requests
from requests import post
from config import client_secret, client_id
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Read the usage_stats.csv file from the Resources folder into a Pandas DataFrame
twitch_zaggle_merged_df = pd.read_csv(
    Path("./Resources/TwitchZaggleMerged.csv")
)
additional_genre = pd.read_csv(
    Path("./Resources/Book1.csv")
)
games = pd.read_csv(
    Path("./Resources/games.csv")
)
# Out:
# /var/folders/tf/l4q9ccl500b9zqywywq4xw7h0000gn/T/ipykernel_6901/720886357.py:2: DtypeWarning: Columns (6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   twitch_zaggle_merged_df = pd.read_csv(

# %%
twitch_zaggle_merged_df.head(20)
# Out:
#                                                  game    year  \
# 0                                 The Tiny Bang Story  2011.0
# 1                      World of Guns: Gun Disassembly  2014.0
# 2   Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                             Hacknet  2015.0
# 4                                           SpaceChem  2011.0
# 5                    Escape Room - Der kranke Kollege  2020.0
# 6                                      Learn to Fly 3  2017.0
# 7                                         Baba Is You  2019.0
# 8                                         Trailmakers  2019.0
# 9                                        Dorfromantik  2022.0
# 10                                        Airport CEO  2021.0
# 11                             Human Resource Machine  2015.0
# 12                                while True: learn()  2019.0
# 13                    Europa Universalis III Complete  2009.0
# 14                                        Opus Magnum  2017.0
# 15                         Supraland Six Inches Under  2022.0
# 16                                         The Bridge  2013.0
# 17                                       SHENZHEN I/O  2016.0
# 18                                            TIS-100  2015.0
# 19                                  Contraption Maker  2014.0
#
#     metacritic_rating  reviewer_rating  positivity_ratio  rating_x  \
# 0                63.0              8.0          7.073879     84.85
# 1                 NaN              8.0          5.208940     82.09
# 2                91.0              6.0          3.581082       NaN
# 3                82.0              8.0         14.548520     91.41
# 4                84.0              8.0         11.440415     88.72
# 5                 NaN              8.0          6.828914       NaN
# 6                 NaN              8.0         15.571125     91.05
# 7                87.0              9.0         49.397183     95.52
# 8                 NaN              8.0         11.906299     89.88
# 9                 NaN              9.0         32.146377     94.80
# 10                NaN              8.0          5.536157     82.16
# 11               78.0              8.0         15.220833     90.26
# 12                NaN              8.0         11.255238     88.89
# 13               83.0              8.0          5.188742       NaN
# 14               90.0              9.0         37.977444     93.82
# 15                NaN              9.0         31.067568     92.40
# 16               74.0              8.0          7.037182     84.57
# 17                NaN              9.0         19.602273     91.35
# 18                NaN              9.0         29.991379     92.84
# 19                NaN              8.0         10.436893     86.48
#
#    primary_genre                                       store_genres  \
# 0      Adventure                   ['Adventure', 'Casual', 'Indie']
# 1           Free  ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# 2            NaN                                                NaN
# 3     Simulation                            ['Indie', 'Simulation']
# 4     Simulation                            ['Indie', 'Simulation']
# 5            NaN                                                NaN
# 6         Casual  ['Action', 'Adventure', 'Casual', 'Free', 'Ind...
# 7          Indie                                          ['Indie']
# 8          Indie  ['Action', 'Adventure', 'Indie', 'Racing', 'Si...
# 9       Strategy      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 10    Simulation                ['Indie', 'Simulation', 'Strategy']
# 11         Indie                  ['Casual', 'Indie', 'Simulation']
# 12         Indie                            ['Indie', 'Simulation']
# 13           NaN                                                NaN
# 14    Simulation                            ['Indie', 'Simulation']
# 15     Adventure                                      ['Adventure']
# 16         Indie       ['Adventure', 'Casual', 'Indie', 'Strategy']
# 17    Simulation                            ['Indie', 'Simulation']
# 18    Simulation                            ['Indie', 'Simulation']
# 19        Casual                  ['Casual', 'Indie', 'Simulation']
#
#                             publisher                      developer  ...  \
# 0                       Colibri Games                  Colibri Games  ...
# 1                  Noble Empire Corp.             Noble Empire Corp.  ...
# 2                                 NaN                            NaN  ...
# 3                    Fellow Traveller         Team Fractal Alligator  ...
# 4                         Zachtronics                    Zachtronics  ...
# 5                                 NaN                            NaN  ...
# 6            Light Bringer Games inc.       Light Bringer Games inc.  ...
# 7                          Hempuli Oy                     Hempuli Oy  ...
# 8                           Flashbulb                      Flashbulb  ...
# 9                 Toukana Interactive            Toukana Interactive  ...
# 10                          Apog Labs                      Apog Labs  ...
# 11               Tomorrow Corporation           Tomorrow Corporation  ...
# 12                           Luden.io                       Luden.io  ...
# 13                                NaN                            NaN  ...
# 14                        Zachtronics                    Zachtronics  ...
# 15                     Supra Games UG                 Supra Games UG  ...
# 16  The Quantum Astrophysicists Guild  Ty Taylor and Mario Castañeda  ...
# 17                        Zachtronics                    Zachtronics  ...
# 18                        Zachtronics                    Zachtronics  ...
# 19                         Top Meadow                     Kevin Ryan  ...
#
#    hypes  parent_game   rating_y  rating_count total_rating  \
# 0    NaN          NaN  72.926984          27.0    71.463492
# 1    NaN          NaN  66.706351           8.0    66.706351
# 2    NaN          NaN        NaN           NaN          NaN
# 3    NaN          NaN  77.907238          31.0    82.953619
# 4    NaN          NaN  83.151954          25.0    83.151954
# 5    NaN          NaN        NaN           NaN          NaN
# 6    NaN          NaN  68.965252           6.0    68.965252
# 7    NaN          NaN        NaN           NaN          NaN
# 8    NaN          NaN  79.936199           6.0    79.936199
# 9    1.0          NaN  78.402629          35.0    78.402629
# 10   2.0          NaN  80.000000           4.0    80.000000
# 11   NaN          NaN  77.648329          37.0    75.990831
# 12   NaN          NaN  75.180587          16.0    72.590294
# 13   NaN          NaN        NaN           NaN          NaN
# 14   1.0          NaN  86.474475          30.0    89.403904
# 15   NaN          NaN        NaN           NaN          NaN
# 16   NaN          NaN  70.324965          69.0    69.662483
# 17   NaN          NaN        NaN           NaN          NaN
# 18   NaN          NaN  70.385402          13.0    70.385402
# 19   NaN          NaN  80.000000           3.0    80.000000
#
#    total_rating_count aggregated_rating aggregated_rating_count  \
# 0                28.0         70.000000                     1.0
# 1                 8.0               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                32.0         88.000000                     1.0
# 4                25.0               NaN                     NaN
# 5                 NaN               NaN                     NaN
# 6                 6.0               NaN                     NaN
# 7                 NaN               NaN                     NaN
# 8                 6.0               NaN                     NaN
# 9                35.0               NaN                     NaN
# 10                4.0               NaN                     NaN
# 11               43.0         74.333333                     6.0
# 12               18.0         70.000000                     2.0
# 13                NaN               NaN                     NaN
# 14               35.0         92.333333                     5.0
# 15                NaN               NaN                     NaN
# 16               77.0         69.000000                     8.0
# 17                NaN               NaN                     NaN
# 18               13.0               NaN                     NaN
# 19                3.0               NaN                     NaN
#
#                                             storyline franchise
# 0                                                 NaN       NaN
# 1                                                 NaN       NaN
# 2                                                 NaN       NaN
# 3   Bit, a hacker responsible for creating the mos...       NaN
# 4                                                 NaN       NaN
# 5                                                 NaN       NaN
# 6                                                 NaN       NaN
# 7                                                 NaN       NaN
# 8                                                 NaN       NaN
# 9                                                 NaN       NaN
# 10                                                NaN       NaN
# 11                                                NaN       NaN
# 12                                                NaN       NaN
# 13                                                NaN       NaN
# 14  “It is not an exaggeration to say that without...       NaN
# 15                                                NaN       NaN
# 16                                                NaN       NaN
# 17                                                NaN       NaN
# 18                                                NaN       NaN
# 19                                                NaN       NaN
#
# [20 rows x 33 columns]

# %%
#length of the merged data
len(twitch_zaggle_merged_df)
# Out:
# 289341

# %%
additional_genre.head()
# Out:
#        id                              game  total_review review_score  \
# 0     730  Counter-Strike: Global Offensive       7382695          88%
# 1  578080               PUBG: BATTLEGROUNDS       2201296          57%
# 2     570                            Dota 2       2017009          82%
# 3  271590                Grand Theft Auto V       1322782       89.85%
# 4  359550   Tom Clancy's Rainbow Six® Siege        978762          86%
#
#   release_date launch_price                                              genre
# 0      8/21/12      $14.99   FPS, Shooter, Multiplayer, Competitive, Action...
# 1     12/21/17      $29.99   Survival, Shooter, Battle Royale, Multiplayer,...
# 2       7/9/13      $29.99   Free to Play, MOBA, Multiplayer, Strategy, eSp...
# 3      4/13/15      $29.99   Open World, Action, Multiplayer, Crime, Automo...
# 4      12/1/15      $59.99   FPS, PvP, eSports, Shooter, Multiplayer, Tacti...

# %%
#Split the "list" into lists
additional_genre['genre'] = additional_genre['genre'].str.split(',')
additional_genre['genre'] = additional_genre['genre'].astype('object')  # Update the data type to 'object'

print(additional_genre.dtypes)
# Out:
# id               int64
# game            object
# total_review     int64
# review_score    object
# release_date    object
# launch_price    object
# genre           object
# dtype: object

# %%
additional_genre.head()
# Out:
#        id                              game  total_review review_score  \
# 0     730  Counter-Strike: Global Offensive       7382695          88%
# 1  578080               PUBG: BATTLEGROUNDS       2201296          57%
# 2     570                            Dota 2       2017009          82%
# 3  271590                Grand Theft Auto V       1322782       89.85%
# 4  359550   Tom Clancy's Rainbow Six® Siege        978762          86%
#
#   release_date launch_price                                              genre
# 0      8/21/12      $14.99   [FPS,  Shooter,  Multiplayer,  Competitive,  A...
# 1     12/21/17      $29.99   [Survival,  Shooter,  Battle Royale,  Multipla...
# 2       7/9/13      $29.99   [Free to Play,  MOBA,  Multiplayer,  Strategy,...
# 3      4/13/15      $29.99   [Open World,  Action,  Multiplayer,  Crime,  A...
# 4      12/1/15      $59.99   [FPS,  PvP,  eSports,  Shooter,  Multiplayer, ...

# %%
# Keep the last occurrence of each duplicate based on the 'game' column
additional_genre = additional_genre.drop_duplicates(subset=['game'], keep='last')

# Now, 'additional_genre' has unique values in the 'game' column

# %%
# Check for duplicate values in the 'game' column of additional_genre
if additional_genre['game'].duplicated().any():
    print("Warning: Duplicate values found in the 'game' column of additional_genre. Please handle duplicates.")

# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['store_genres'] = twitch_zaggle_merged_df['store_genres'].fillna(
    twitch_zaggle_merged_df['game'].map(additional_genre.set_index('game')['genre'])
)

# %%
games.head()
# Out:
#                                       Name ReleaseDate  ReleaseYear  \
# 0               20th Century Video Almanac         NaN       1993.0
# 1                                 3D Atlas         NaN       1994.0
# 2                           3DO Action Pak         NaN       1995.0
# 3                    3DO Demo Disc Program         NaN          NaN
# 4  3DO Magazine: Interactive Sampler No 02         NaN          NaN
#
#                 Developer                     Platform      Genres  \
# 0  The Software Toolworks  3DO Interactive Multiplayer   Education
# 1         Electronic Arts  3DO Interactive Multiplayer   Education
# 2         The 3DO Company  3DO Interactive Multiplayer      Action
# 3                     NaN  3DO Interactive Multiplayer         NaN
# 4  Crystal Dynamics, Inc.  3DO Interactive Multiplayer         NaN
#
#                 Publisher  MaxPlayers          ESRB  \
# 0  The Software Toolworks         1.0     Not Rated
# 1         Electronic Arts         1.0  E - Everyone
# 2         The 3DO Company         1.0     Not Rated
# 3                     NaN         NaN           NaN
# 4  Crystal Dynamics, Inc.         1.0           NaN
#
#                                             Overview  Cooperative
# 0  In The Best of Our Century, we've taken multim...        False
# 1  3D Atlas for 3DO is an extremely data and art ...        False
# 2  This is a four-game compilation pack that cont...        False
# 3  A white binder with blue silk-screened art. Th...        False
# 4  Has trailers of Gex, and a game called Cybercl...        False

# %%
# Keep the last occurrence of each duplicate based on the 'game' column
games = games.drop_duplicates(subset=['Name'], keep='last')

# Now, 'additional_genre' has unique values in the 'game' column

# %%
# Check for duplicate values in the 'game' column of games
if games['Name'].duplicated().any():
    print("Warning: Duplicate values found in the 'Name' column of games. Please handle duplicates.")

# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and games
twitch_zaggle_merged_df['storyline'] = twitch_zaggle_merged_df['storyline'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Overview'])
)

# %%
twitch_zaggle_merged_df.head()
# Out:
#                                                 game    year  \
# 0                                The Tiny Bang Story  2011.0
# 1                     World of Guns: Gun Disassembly  2014.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                            Hacknet  2015.0
# 4                                          SpaceChem  2011.0
#
#    metacritic_rating  reviewer_rating  positivity_ratio  rating_x  \
# 0               63.0              8.0          7.073879     84.85
# 1                NaN              8.0          5.208940     82.09
# 2               91.0              6.0          3.581082       NaN
# 3               82.0              8.0         14.548520     91.41
# 4               84.0              8.0         11.440415     88.72
#
#   primary_genre                                       store_genres  \
# 0     Adventure                   ['Adventure', 'Casual', 'Indie']
# 1          Free  ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# 2           NaN  [Simulation,  Flight,  Realistic,  Open World,...
# 3    Simulation                            ['Indie', 'Simulation']
# 4    Simulation                            ['Indie', 'Simulation']
#
#             publisher               developer  ... hypes  parent_game  \
# 0       Colibri Games           Colibri Games  ...   NaN          NaN
# 1  Noble Empire Corp.      Noble Empire Corp.  ...   NaN          NaN
# 2                 NaN                     NaN  ...   NaN          NaN
# 3    Fellow Traveller  Team Fractal Alligator  ...   NaN          NaN
# 4         Zachtronics             Zachtronics  ...   NaN          NaN
#
#     rating_y  rating_count total_rating total_rating_count aggregated_rating  \
# 0  72.926984          27.0    71.463492               28.0              70.0
# 1  66.706351           8.0    66.706351                8.0               NaN
# 2        NaN           NaN          NaN                NaN               NaN
# 3  77.907238          31.0    82.953619               32.0              88.0
# 4  83.151954          25.0    83.151954               25.0               NaN
#
#   aggregated_rating_count                                          storyline  \
# 0                     1.0  Life on Tiny Planet was calm and carefree unti...
# 1                     NaN  World of Guns: Gun Disassembly lets you delve ...
# 2                     NaN                                                NaN
# 3                     1.0  Bit, a hacker responsible for creating the mos...
# 4                     NaN  SpaceChem is a puzzle game about chemical engi...
#
#   franchise
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 33 columns]

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['store_genres'] = twitch_zaggle_merged_df['store_genres'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Genres'])
)

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['year'] = twitch_zaggle_merged_df['year'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['ReleaseYear'])
)

# %%
# Assuming 'game' is a common identifier between twitch_zaggle_merged_df and additional_genre
twitch_zaggle_merged_df['publisher'] = twitch_zaggle_merged_df['publisher'].fillna(
    twitch_zaggle_merged_df['game'].map(games.set_index('Name')['Publisher'])
)

# %%
len(twitch_zaggle_merged_df)
# Out:
# 289341

# %%
twitch_zaggle_merged_df
# Out:
#                                                      game    year  \
# 0                                     The Tiny Bang Story  2011.0
# 1                          World of Guns: Gun Disassembly  2014.0
# 2       Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                                 Hacknet  2015.0
# 4                                               SpaceChem  2011.0
# ...                                                   ...     ...
# 289336                                      Voxel Drivers     NaN
# 289337                  A Life in Silk: The First Cumming     NaN
# 289338                                       Black Hornet  1991.0
# 289339                                          Dig-N-Rig     NaN
# 289340                        Townsmen: A Kingdom Rebuilt     NaN
#
#         metacritic_rating  reviewer_rating  positivity_ratio  rating_x  \
# 0                    63.0              8.0          7.073879     84.85
# 1                     NaN              8.0          5.208940     82.09
# 2                    91.0              6.0          3.581082       NaN
# 3                    82.0              8.0         14.548520     91.41
# 4                    84.0              8.0         11.440415     88.72
# ...                   ...              ...               ...       ...
# 289336                NaN              NaN               NaN       NaN
# 289337                NaN              NaN               NaN       NaN
# 289338                NaN              NaN               NaN       NaN
# 289339                NaN              NaN               NaN       NaN
# 289340                NaN              NaN               NaN       NaN
#
#        primary_genre                                       store_genres  \
# 0          Adventure                   ['Adventure', 'Casual', 'Indie']
# 1               Free  ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# 2                NaN  [Simulation,  Flight,  Realistic,  Open World,...
# 3         Simulation                            ['Indie', 'Simulation']
# 4         Simulation                            ['Indie', 'Simulation']
# ...              ...                                                ...
# 289336           NaN                                                NaN
# 289337           NaN                                                NaN
# 289338           NaN                                            Shooter
# 289339           NaN                                                NaN
# 289340           NaN                                           Strategy
#
#                    publisher               developer  ... hypes  parent_game  \
# 0              Colibri Games           Colibri Games  ...   NaN          NaN
# 1         Noble Empire Corp.      Noble Empire Corp.  ...   NaN          NaN
# 2                        NaN                     NaN  ...   NaN          NaN
# 3           Fellow Traveller  Team Fractal Alligator  ...   NaN          NaN
# 4                Zachtronics             Zachtronics  ...   NaN          NaN
# ...                      ...                     ...  ...   ...          ...
# 289336                   NaN                     NaN  ...   NaN          NaN
# 289337                   NaN                     NaN  ...   3.0          NaN
# 289338  Hi-Tec Software Ltd.                     NaN  ...   NaN          NaN
# 289339                   NaN                     NaN  ...   NaN          NaN
# 289340            HandyGames                     NaN  ...   2.0      32428.0
#
#          rating_y  rating_count total_rating total_rating_count  \
# 0       72.926984          27.0    71.463492               28.0
# 1       66.706351           8.0    66.706351                8.0
# 2             NaN           NaN          NaN                NaN
# 3       77.907238          31.0    82.953619               32.0
# 4       83.151954          25.0    83.151954               25.0
# ...           ...           ...          ...                ...
# 289336  40.000000           0.0    40.000000                0.0
# 289337  77.373272          13.0    77.373272               13.0
# 289338        NaN           NaN          NaN                NaN
# 289339        NaN           NaN          NaN                NaN
# 289340  50.000000           1.0    50.000000                1.0
#
#        aggregated_rating aggregated_rating_count  \
# 0                   70.0                     1.0
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                   88.0                     1.0
# 4                    NaN                     NaN
# ...                  ...                     ...
# 289336               NaN                     NaN
# 289337               NaN                     NaN
# 289338               NaN                     NaN
# 289339               NaN                     NaN
# 289340               NaN                     NaN
#
#                                                 storyline franchise
# 0       Life on Tiny Planet was calm and carefree unti...       NaN
# 1       World of Guns: Gun Disassembly lets you delve ...       NaN
# 2                                                     NaN       NaN
# 3       Bit, a hacker responsible for creating the mos...       NaN
# 4       SpaceChem is a puzzle game about chemical engi...       NaN
# ...                                                   ...       ...
# 289336                                                NaN       NaN
# 289337  A Life in Silk is a highly-interactive visual-...       NaN
# 289338  You pilot the Black Hornet, an advanced stealt...       NaN
# 289339                                                NaN       NaN
# 289340  Townsmen – A Kingdom Rebuilt hands the crown t...       NaN
#
# [289341 rows x 33 columns]

# %%
# Specify the columns to check for NaN values
columns_to_check = ['year', 'metacritic_rating', 'reviewer_rating', 'positivity_ratio', 'rating_x', 'primary_genre', 'store_genres', 'publisher', 'developer', 'hypes', 'parent_game', 'rating_y', 'rating_count', 'total_rating', 'total_rating_count', 'aggregated_rating', 'aggregated_rating_count', 'storyline', 'franchise']

# Drop rows where all values in the specified columns are NaN
twitch_zaggle_merged_df = twitch_zaggle_merged_df.dropna(subset=columns_to_check, how='all')

# %%
len(twitch_zaggle_merged_df)
# Out:
# 174300

# %%
#88,023 before additional info
#115,041 after additional info

# %% [markdown]
# #K-Means Clustering

# %%
twitch_zaggle_merged_df.set_index('game', inplace=True)
twitch_zaggle_merged_df
# Out:
#                                                       year  metacritic_rating  \
# game
# The Tiny Bang Story                                 2011.0               63.0
# World of Guns: Gun Disassembly                      2014.0                NaN
# Microsoft Flight Simulator 40th Anniversary Edi...  2020.0               91.0
# Hacknet                                             2015.0               82.0
# SpaceChem                                           2011.0               84.0
# ...                                                    ...                ...
# The Backyard                                        1993.0                NaN
# Voxel Drivers                                          NaN                NaN
# A Life in Silk: The First Cumming                      NaN                NaN
# Black Hornet                                        1991.0                NaN
# Townsmen: A Kingdom Rebuilt                            NaN                NaN
#
#                                                     reviewer_rating  \
# game
# The Tiny Bang Story                                             8.0
# World of Guns: Gun Disassembly                                  8.0
# Microsoft Flight Simulator 40th Anniversary Edi...              6.0
# Hacknet                                                         8.0
# SpaceChem                                                       8.0
# ...                                                             ...
# The Backyard                                                    NaN
# Voxel Drivers                                                   NaN
# A Life in Silk: The First Cumming                               NaN
# Black Hornet                                                    NaN
# Townsmen: A Kingdom Rebuilt                                     NaN
#
#                                                     positivity_ratio  \
# game
# The Tiny Bang Story                                         7.073879
# World of Guns: Gun Disassembly                              5.208940
# Microsoft Flight Simulator 40th Anniversary Edi...          3.581082
# Hacknet                                                    14.548520
# SpaceChem                                                  11.440415
# ...                                                              ...
# The Backyard                                                     NaN
# Voxel Drivers                                                    NaN
# A Life in Silk: The First Cumming                                NaN
# Black Hornet                                                     NaN
# Townsmen: A Kingdom Rebuilt                                      NaN
#
#                                                     rating_x primary_genre  \
# game
# The Tiny Bang Story                                    84.85     Adventure
# World of Guns: Gun Disassembly                         82.09          Free
# Microsoft Flight Simulator 40th Anniversary Edi...       NaN           NaN
# Hacknet                                                91.41    Simulation
# SpaceChem                                              88.72    Simulation
# ...                                                      ...           ...
# The Backyard                                             NaN           NaN
# Voxel Drivers                                            NaN           NaN
# A Life in Silk: The First Cumming                        NaN           NaN
# Black Hornet                                             NaN           NaN
# Townsmen: A Kingdom Rebuilt                              NaN           NaN
#
#                                                                                          store_genres  \
# game
# The Tiny Bang Story                                                  ['Adventure', 'Casual', 'Indie']
# World of Guns: Gun Disassembly                      ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# Microsoft Flight Simulator 40th Anniversary Edi...  [Simulation,  Flight,  Realistic,  Open World,...
# Hacknet                                                                       ['Indie', 'Simulation']
# SpaceChem                                                                     ['Indie', 'Simulation']
# ...                                                                                               ...
# The Backyard                                                                                      NaN
# Voxel Drivers                                                                                     NaN
# A Life in Silk: The First Cumming                                                                 NaN
# Black Hornet                                                                                  Shooter
# Townsmen: A Kingdom Rebuilt                                                                  Strategy
#
#                                                                publisher  \
# game
# The Tiny Bang Story                                        Colibri Games
# World of Guns: Gun Disassembly                        Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                   NaN
# Hacknet                                                 Fellow Traveller
# SpaceChem                                                    Zachtronics
# ...                                                                  ...
# The Backyard                                         Broderbund Software
# Voxel Drivers                                                        NaN
# A Life in Silk: The First Cumming                                    NaN
# Black Hornet                                        Hi-Tec Software Ltd.
# Townsmen: A Kingdom Rebuilt                                   HandyGames
#
#                                                                  developer  \
# game
# The Tiny Bang Story                                          Colibri Games
# World of Guns: Gun Disassembly                          Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                             Team Fractal Alligator
# SpaceChem                                                      Zachtronics
# ...                                                                    ...
# The Backyard                                                           NaN
# Voxel Drivers                                                          NaN
# A Life in Silk: The First Cumming                                      NaN
# Black Hornet                                                           NaN
# Townsmen: A Kingdom Rebuilt                                            NaN
#
#                                                                                             tags_list  \
# game
# The Tiny Bang Story                                 ['Story Rich', 'Steampunk', 'Adventure', 'Atmo...
# World of Guns: Gun Disassembly                      ['Horror', 'First-Person', 'Historical', 'Mult...
# Microsoft Flight Simulator 40th Anniversary Edi...  ['Multiplayer', 'Adventure', 'VR', 'Action Rog...
# Hacknet                                             ['Horror', 'Story Rich', 'Hacking', 'Crime', '...
# SpaceChem                                           ['Automation', 'Strategy', 'Building', 'Puzzle...
# ...                                                                                               ...
# The Backyard                                                                                      NaN
# Voxel Drivers                                                                                     NaN
# A Life in Silk: The First Cumming                                                                 NaN
# Black Hornet                                                                                      NaN
# Townsmen: A Kingdom Rebuilt                                                                       NaN
#
#                                                     ...  hypes parent_game  \
# game                                                ...
# The Tiny Bang Story                                 ...    NaN         NaN
# World of Guns: Gun Disassembly                      ...    NaN         NaN
# Microsoft Flight Simulator 40th Anniversary Edi...  ...    NaN         NaN
# Hacknet                                             ...    NaN         NaN
# SpaceChem                                           ...    NaN         NaN
# ...                                                 ...    ...         ...
# The Backyard                                        ...    NaN         NaN
# Voxel Drivers                                       ...    NaN         NaN
# A Life in Silk: The First Cumming                   ...    3.0         NaN
# Black Hornet                                        ...    NaN         NaN
# Townsmen: A Kingdom Rebuilt                         ...    2.0     32428.0
#
#                                                      rating_y rating_count  \
# game
# The Tiny Bang Story                                 72.926984         27.0
# World of Guns: Gun Disassembly                      66.706351          8.0
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN          NaN
# Hacknet                                             77.907238         31.0
# SpaceChem                                           83.151954         25.0
# ...                                                       ...          ...
# The Backyard                                              NaN          NaN
# Voxel Drivers                                       40.000000          0.0
# A Life in Silk: The First Cumming                   77.373272         13.0
# Black Hornet                                              NaN          NaN
# Townsmen: A Kingdom Rebuilt                         50.000000          1.0
#
#                                                    total_rating  \
# game
# The Tiny Bang Story                                   71.463492
# World of Guns: Gun Disassembly                        66.706351
# Microsoft Flight Simulator 40th Anniversary Edi...          NaN
# Hacknet                                               82.953619
# SpaceChem                                             83.151954
# ...                                                         ...
# The Backyard                                                NaN
# Voxel Drivers                                         40.000000
# A Life in Silk: The First Cumming                     77.373272
# Black Hornet                                                NaN
# Townsmen: A Kingdom Rebuilt                           50.000000
#
#                                                    total_rating_count  \
# game
# The Tiny Bang Story                                              28.0
# World of Guns: Gun Disassembly                                    8.0
# Microsoft Flight Simulator 40th Anniversary Edi...                NaN
# Hacknet                                                          32.0
# SpaceChem                                                        25.0
# ...                                                               ...
# The Backyard                                                      NaN
# Voxel Drivers                                                     0.0
# A Life in Silk: The First Cumming                                13.0
# Black Hornet                                                      NaN
# Townsmen: A Kingdom Rebuilt                                       1.0
#
#                                                    aggregated_rating  \
# game
# The Tiny Bang Story                                             70.0
# World of Guns: Gun Disassembly                                   NaN
# Microsoft Flight Simulator 40th Anniversary Edi...               NaN
# Hacknet                                                         88.0
# SpaceChem                                                        NaN
# ...                                                              ...
# The Backyard                                                     NaN
# Voxel Drivers                                                    NaN
# A Life in Silk: The First Cumming                                NaN
# Black Hornet                                                     NaN
# Townsmen: A Kingdom Rebuilt                                      NaN
#
#                                                    aggregated_rating_count  \
# game
# The Tiny Bang Story                                                    1.0
# World of Guns: Gun Disassembly                                         NaN
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                                                1.0
# SpaceChem                                                              NaN
# ...                                                                    ...
# The Backyard                                                           NaN
# Voxel Drivers                                                          NaN
# A Life in Silk: The First Cumming                                      NaN
# Black Hornet                                                           NaN
# Townsmen: A Kingdom Rebuilt                                            NaN
#
#                                                                                             storyline  \
# game
# The Tiny Bang Story                                 Life on Tiny Planet was calm and carefree unti...
# World of Guns: Gun Disassembly                      World of Guns: Gun Disassembly lets you delve ...
# Microsoft Flight Simulator 40th Anniversary Edi...                                                NaN
# Hacknet                                             Bit, a hacker responsible for creating the mos...
# SpaceChem                                           SpaceChem is a puzzle game about chemical engi...
# ...                                                                                               ...
# The Backyard                                        The Backyard is an educational game for toddle...
# Voxel Drivers                                                                                     NaN
# A Life in Silk: The First Cumming                   A Life in Silk is a highly-interactive visual-...
# Black Hornet                                        You pilot the Black Hornet, an advanced stealt...
# Townsmen: A Kingdom Rebuilt                         Townsmen – A Kingdom Rebuilt hands the crown t...
#
#                                                     franchise
# game
# The Tiny Bang Story                                       NaN
# World of Guns: Gun Disassembly                            NaN
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN
# Hacknet                                                   NaN
# SpaceChem                                                 NaN
# ...                                                       ...
# The Backyard                                              NaN
# Voxel Drivers                                             NaN
# A Life in Silk: The First Cumming                         NaN
# Black Hornet                                              NaN
# Townsmen: A Kingdom Rebuilt                               NaN
#
# [174300 rows x 32 columns]

# %%
twitch_zaggle_merged_df.head()
# Out:
#                                                       year  metacritic_rating  \
# game
# The Tiny Bang Story                                 2011.0               63.0
# World of Guns: Gun Disassembly                      2014.0                NaN
# Microsoft Flight Simulator 40th Anniversary Edi...  2020.0               91.0
# Hacknet                                             2015.0               82.0
# SpaceChem                                           2011.0               84.0
#
#                                                     reviewer_rating  \
# game
# The Tiny Bang Story                                             8.0
# World of Guns: Gun Disassembly                                  8.0
# Microsoft Flight Simulator 40th Anniversary Edi...              6.0
# Hacknet                                                         8.0
# SpaceChem                                                       8.0
#
#                                                     positivity_ratio  \
# game
# The Tiny Bang Story                                         7.073879
# World of Guns: Gun Disassembly                              5.208940
# Microsoft Flight Simulator 40th Anniversary Edi...          3.581082
# Hacknet                                                    14.548520
# SpaceChem                                                  11.440415
#
#                                                     rating_x primary_genre  \
# game
# The Tiny Bang Story                                    84.85     Adventure
# World of Guns: Gun Disassembly                         82.09          Free
# Microsoft Flight Simulator 40th Anniversary Edi...       NaN           NaN
# Hacknet                                                91.41    Simulation
# SpaceChem                                              88.72    Simulation
#
#                                                                                          store_genres  \
# game
# The Tiny Bang Story                                                  ['Adventure', 'Casual', 'Indie']
# World of Guns: Gun Disassembly                      ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# Microsoft Flight Simulator 40th Anniversary Edi...  [Simulation,  Flight,  Realistic,  Open World,...
# Hacknet                                                                       ['Indie', 'Simulation']
# SpaceChem                                                                     ['Indie', 'Simulation']
#
#                                                              publisher  \
# game
# The Tiny Bang Story                                      Colibri Games
# World of Guns: Gun Disassembly                      Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                 NaN
# Hacknet                                               Fellow Traveller
# SpaceChem                                                  Zachtronics
#
#                                                                  developer  \
# game
# The Tiny Bang Story                                          Colibri Games
# World of Guns: Gun Disassembly                          Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                             Team Fractal Alligator
# SpaceChem                                                      Zachtronics
#
#                                                                                             tags_list  \
# game
# The Tiny Bang Story                                 ['Story Rich', 'Steampunk', 'Adventure', 'Atmo...
# World of Guns: Gun Disassembly                      ['Horror', 'First-Person', 'Historical', 'Mult...
# Microsoft Flight Simulator 40th Anniversary Edi...  ['Multiplayer', 'Adventure', 'VR', 'Action Rog...
# Hacknet                                             ['Horror', 'Story Rich', 'Hacking', 'Crime', '...
# SpaceChem                                           ['Automation', 'Strategy', 'Building', 'Puzzle...
#
#                                                     ...  hypes parent_game  \
# game                                                ...
# The Tiny Bang Story                                 ...    NaN         NaN
# World of Guns: Gun Disassembly                      ...    NaN         NaN
# Microsoft Flight Simulator 40th Anniversary Edi...  ...    NaN         NaN
# Hacknet                                             ...    NaN         NaN
# SpaceChem                                           ...    NaN         NaN
#
#                                                      rating_y rating_count  \
# game
# The Tiny Bang Story                                 72.926984         27.0
# World of Guns: Gun Disassembly                      66.706351          8.0
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN          NaN
# Hacknet                                             77.907238         31.0
# SpaceChem                                           83.151954         25.0
#
#                                                    total_rating  \
# game
# The Tiny Bang Story                                   71.463492
# World of Guns: Gun Disassembly                        66.706351
# Microsoft Flight Simulator 40th Anniversary Edi...          NaN
# Hacknet                                               82.953619
# SpaceChem                                             83.151954
#
#                                                    total_rating_count  \
# game
# The Tiny Bang Story                                              28.0
# World of Guns: Gun Disassembly                                    8.0
# Microsoft Flight Simulator 40th Anniversary Edi...                NaN
# Hacknet                                                          32.0
# SpaceChem                                                        25.0
#
#                                                    aggregated_rating  \
# game
# The Tiny Bang Story                                             70.0
# World of Guns: Gun Disassembly                                   NaN
# Microsoft Flight Simulator 40th Anniversary Edi...               NaN
# Hacknet                                                         88.0
# SpaceChem                                                        NaN
#
#                                                    aggregated_rating_count  \
# game
# The Tiny Bang Story                                                    1.0
# World of Guns: Gun Disassembly                                         NaN
# Microsoft Flight Simulator 40th Anniversary Edi...                     NaN
# Hacknet                                                                1.0
# SpaceChem                                                              NaN
#
#                                                                                             storyline  \
# game
# The Tiny Bang Story                                 Life on Tiny Planet was calm and carefree unti...
# World of Guns: Gun Disassembly                      World of Guns: Gun Disassembly lets you delve ...
# Microsoft Flight Simulator 40th Anniversary Edi...                                                NaN
# Hacknet                                             Bit, a hacker responsible for creating the mos...
# SpaceChem                                           SpaceChem is a puzzle game about chemical engi...
#
#                                                     franchise
# game
# The Tiny Bang Story                                       NaN
# World of Guns: Gun Disassembly                            NaN
# Microsoft Flight Simulator 40th Anniversary Edi...        NaN
# Hacknet                                                   NaN
# SpaceChem                                                 NaN
#
# [5 rows x 32 columns]

# %%
# Generate summary statistics
twitch_zaggle_merged_df.describe()
# Out:
#                year  metacritic_rating  reviewer_rating  positivity_ratio  \
# count  98243.000000        4338.000000     49812.000000      69727.000000
# mean    2015.331759          72.618027         6.368626          5.056642
# std       32.419114          10.756642         1.370301          8.506306
# min       19.000000          20.000000         1.000000          0.020000
# 25%     2016.000000          67.000000         5.000000          1.250000
# 50%     2019.000000          74.000000         6.000000          2.666667
# 75%     2021.000000          80.000000         8.000000          5.666667
# max     2023.000000          97.000000         9.000000        591.000000
#
#            rating_x             id  first_release_date       follows  \
# count  76239.000000  149047.000000        1.179030e+05  22142.000000
# mean      64.847944  121907.204600        1.339560e+09     11.297082
# std       14.120138   79866.783719        3.474298e+08     47.115476
# min       15.090000       1.000000       -6.107616e+08      1.000000
# 25%       56.000000   45133.500000        1.164931e+09      1.000000
# 50%       66.330000  121415.000000        1.487894e+09      2.000000
# 75%       75.100000  188548.000000        1.595376e+09      5.000000
# max       97.540000  277234.000000        1.894406e+09   1798.000000
#
#              hypes    parent_game      rating_y  rating_count  total_rating  \
# count  9841.000000   32350.000000  30424.000000  30424.000000  35754.000000
# mean      3.677878   63664.510479     66.488988     22.929464     66.403659
# std      17.561549   71968.369471     14.337726    111.362367     14.694040
# min       1.000000       1.000000     10.015294      0.000000      0.000000
# 25%       1.000000    3193.000000     59.000000      0.000000     58.750000
# 50%       1.000000   26764.000000     70.000000      2.000000     70.000000
# 75%       2.000000  119133.000000     77.754969     10.000000     77.500000
# max    1038.000000  276958.000000    100.000000   4098.000000    100.000000
#
#        total_rating_count  aggregated_rating  aggregated_rating_count  \
# count        35754.000000       15321.000000             15321.000000
# mean            21.060525          69.097603                 3.615430
# std            104.396990          16.130055                 4.047096
# min              0.000000           0.000000                 0.000000
# 25%              0.000000          60.000000                 1.000000
# 50%              2.000000          71.666667                 2.000000
# 75%              9.000000          80.000000                 4.000000
# max           4135.000000         100.000000                59.000000
#
#          franchise
# count  1515.000000
# mean    132.287129
# std     122.077833
# min       1.000000
# 25%      26.000000
# 50%      92.000000
# 75%     222.000000
# max     444.000000

# %%
twitch_zaggle_merged_df.shape
# Out:
# (174300, 32)

# %%
# Plot your data to see what's in your DataFrame
#twitch_zaggle_merged_df.hvplot.line(
#    width=800,
#    height=400,
#    rot=90
#)

# %% [markdown]
# #Prepare the Data¶

# %%
twitch_zaggle_merged_df.columns
# Out:
# Index(['year', 'metacritic_rating', 'reviewer_rating', 'positivity_ratio',
#        'rating_x', 'primary_genre', 'store_genres', 'publisher', 'developer',
#        'tags_list', 'id', 'age_ratings', 'first_release_date', 'game_modes',
#        'genres', 'platforms', 'release_dates', 'summary', 'themes', 'follows',
#        'keywords', 'collections', 'hypes', 'parent_game', 'rating_y',
#        'rating_count', 'total_rating', 'total_rating_count',
#        'aggregated_rating', 'aggregated_rating_count', 'storyline',
#        'franchise'],
#       dtype='object')

# %%
twitch_zaggle_merged_df = twitch_zaggle_merged_df.drop('summary', axis=1)

# %%
twitch_zaggle_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174300 entries, The Tiny Bang Story to Townsmen: A Kingdom Rebuilt
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     98243 non-null   float64
#  1   metacritic_rating        4338 non-null    float64
#  2   reviewer_rating          49812 non-null   float64
#  3   positivity_ratio         69727 non-null   float64
#  4   rating_x                 76239 non-null   float64
#  5   primary_genre            76229 non-null   object
#  6   store_genres             122830 non-null  object
#  7   publisher                110866 non-null  object
#  8   developer                76102 non-null   object
#  9   tags_list                72443 non-null   object
#  10  id                       149047 non-null  float64
#  11  age_ratings              41841 non-null   object
#  12  first_release_date       117903 non-null  float64
#  13  game_modes               98630 non-null   object
#  14  genres                   134121 non-null  object
#  15  platforms                122054 non-null  object
#  16  release_dates            121646 non-null  object
#  17  themes                   94145 non-null   object
#  18  follows                  22142 non-null   float64
#  19  keywords                 59423 non-null   object
#  20  collections              2159 non-null    object
#  21  hypes                    9841 non-null    float64
#  22  parent_game              32350 non-null   float64
#  23  rating_y                 30424 non-null   float64
#  24  rating_count             30424 non-null   float64
#  25  total_rating             35754 non-null   float64
#  26  total_rating_count       35754 non-null   float64
#  27  aggregated_rating        15321 non-null   float64
#  28  aggregated_rating_count  15321 non-null   float64
#  29  storyline                66919 non-null   object
#  30  franchise                1515 non-null    float64
# dtypes: float64(17), object(14)
# memory usage: 42.6+ MB

# %%
# Identify columns with missing values
columns_with_missing_values = twitch_zaggle_merged_df.columns[twitch_zaggle_merged_df.isnull().any()].tolist()
columns_with_missing_values
# Out:
# ['year',
#  'metacritic_rating',
#  'reviewer_rating',
#  'positivity_ratio',
#  'rating_x',
#  'primary_genre',
#  'store_genres',
#  'publisher',
#  'developer',
#  'tags_list',
#  'id',
#  'age_ratings',
#  'first_release_date',
#  'game_modes',
#  'genres',
#  'platforms',
#  'release_dates',
#  'themes',
#  'follows',
#  'keywords',
#  'collections',
#  'hypes',
#  'parent_game',
#  'rating_y',
#  'rating_count',
#  'total_rating',
#  'total_rating_count',
#  'aggregated_rating',
#  'aggregated_rating_count',
#  'storyline',
#  'franchise']

# %%
# for column in columns_with_missing_values:
#     print(f"Processing column: {column}")
    
#     if twitch_zaggle_merged_df[column].dtype == 'float64':
#         imputer = SimpleImputer(strategy='mean')
#     else:
#         imputer = SimpleImputer(strategy='most_frequent')
    
#     # Flatten lists and handle NaN values
#     flattened_values = twitch_zaggle_merged_df[column].apply(lambda x: x if isinstance(x, list) else [x])
#     flattened_values = flattened_values.apply(lambda x: x[0] if len(x) > 0 else np.nan)
    
#     imputed_values = imputer.fit_transform(flattened_values.values.reshape(-1, 1)).ravel()
    
#     print(f"Imputed values: {imputed_values}")
    
#     # Update the DataFrame using loc
#     twitch_zaggle_merged_df.loc[:, column] = imputed_values


for column in columns_with_missing_values:
    print(f"Processing column: {column}")
    
    if twitch_zaggle_merged_df[column].dtype == 'float64':
        imputed_values = twitch_zaggle_merged_df[column].fillna(twitch_zaggle_merged_df[column].mean())
    else:
        # For non-numeric columns, fill missing values with the most frequent value
        most_frequent_value = twitch_zaggle_merged_df[column].mode().iloc[0]
        imputed_values = twitch_zaggle_merged_df[column].fillna(most_frequent_value)
    
    print(f"Imputed values: {imputed_values}")
    
    # Update the DataFrame using loc
    twitch_zaggle_merged_df.loc[:, column] = imputed_values
# Out:
# Processing column: year
# Imputed values: game
# The Tiny Bang Story                                    2011.000000
# World of Guns: Gun Disassembly                         2014.000000
# Microsoft Flight Simulator 40th Anniversary Edition    2020.000000
# Hacknet                                                2015.000000
# SpaceChem                                              2011.000000
#                                                           ...
# The Backyard                                           1993.000000
# Voxel Drivers                                          2015.331759
# A Life in Silk: The First Cumming                      2015.331759
# Black Hornet                                           1991.000000
# Townsmen: A Kingdom Rebuilt                            2015.331759
# Name: year, Length: 174300, dtype: float64
# Processing column: metacritic_rating
# Imputed values: game
# The Tiny Bang Story                                    63.000000
# World of Guns: Gun Disassembly                         72.618027
# Microsoft Flight Simulator 40th Anniversary Edition    91.000000
# Hacknet                                                82.000000
# SpaceChem                                              84.000000
#                                                          ...
# The Backyard                                           72.618027
# Voxel Drivers                                          72.618027
# A Life in Silk: The First Cumming                      72.618027
# Black Hornet                                           72.618027
# Townsmen: A Kingdom Rebuilt                            72.618027
# Name: metacritic_rating, Length: 174300, dtype: float64
# Processing column: reviewer_rating
# Imputed values: game
# The Tiny Bang Story                                    8.000000
# World of Guns: Gun Disassembly                         8.000000
# Microsoft Flight Simulator 40th Anniversary Edition    6.000000
# Hacknet                                                8.000000
# SpaceChem                                              8.000000
#                                                          ...
# The Backyard                                           6.368626
# Voxel Drivers                                          6.368626
# A Life in Silk: The First Cumming                      6.368626
# Black Hornet                                           6.368626
# Townsmen: A Kingdom Rebuilt                            6.368626
# Name: reviewer_rating, Length: 174300, dtype: float64
# Processing column: positivity_ratio
# Imputed values: game
# The Tiny Bang Story                                     7.073879
# World of Guns: Gun Disassembly                          5.208940
# Microsoft Flight Simulator 40th Anniversary Edition     3.581082
# Hacknet                                                14.548520
# SpaceChem                                              11.440415
#                                                          ...
# The Backyard                                            5.056642
# Voxel Drivers                                           5.056642
# A Life in Silk: The First Cumming                       5.056642
# Black Hornet                                            5.056642
# Townsmen: A Kingdom Rebuilt                             5.056642
# Name: positivity_ratio, Length: 174300, dtype: float64
# Processing column: rating_x
# Imputed values: game
# The Tiny Bang Story                                    84.850000
# World of Guns: Gun Disassembly                         82.090000
# Microsoft Flight Simulator 40th Anniversary Edition    64.847944
# Hacknet                                                91.410000
# SpaceChem                                              88.720000
#                                                          ...
# The Backyard                                           64.847944
# Voxel Drivers                                          64.847944
# A Life in Silk: The First Cumming                      64.847944
# Black Hornet                                           64.847944
# Townsmen: A Kingdom Rebuilt                            64.847944
# Name: rating_x, Length: 174300, dtype: float64
# Processing column: primary_genre
# Imputed values: game
# The Tiny Bang Story                                     Adventure
# World of Guns: Gun Disassembly                               Free
# Microsoft Flight Simulator 40th Anniversary Edition         Indie
# Hacknet                                                Simulation
# SpaceChem                                              Simulation
#                                                           ...
# The Backyard                                                Indie
# Voxel Drivers                                               Indie
# A Life in Silk: The First Cumming                           Indie
# Black Hornet                                                Indie
# Townsmen: A Kingdom Rebuilt                                 Indie
# Name: primary_genre, Length: 174300, dtype: object
# Processing column: store_genres
# Imputed values: game
# The Tiny Bang Story                                                     ['Adventure', 'Casual', 'Indie']
# World of Guns: Gun Disassembly                         ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# Microsoft Flight Simulator 40th Anniversary Edition    [Simulation,  Flight,  Realistic,  Open World,...
# Hacknet                                                                          ['Indie', 'Simulation']
# SpaceChem                                                                        ['Indie', 'Simulation']
#                                                                              ...
# The Backyard                                                                                      Action
# Voxel Drivers                                                                                     Action
# A Life in Silk: The First Cumming                                                                 Action
# Black Hornet                                                                                     Shooter
# Townsmen: A Kingdom Rebuilt                                                                     Strategy
# Name: store_genres, Length: 174300, dtype: object
# Processing column: publisher
# Imputed values: game
# The Tiny Bang Story                                           Colibri Games
# World of Guns: Gun Disassembly                           Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edition                    Sega
# Hacknet                                                    Fellow Traveller
# SpaceChem                                                       Zachtronics
#                                                                ...
# The Backyard                                            Broderbund Software
# Voxel Drivers                                                          Sega
# A Life in Silk: The First Cumming                                      Sega
# Black Hornet                                           Hi-Tec Software Ltd.
# Townsmen: A Kingdom Rebuilt                                      HandyGames
# Name: publisher, Length: 174300, dtype: object
# Processing column: developer
# Imputed values: game
# The Tiny Bang Story                                             Colibri Games
# World of Guns: Gun Disassembly                             Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edition           Choice of Games
# Hacknet                                                Team Fractal Alligator
# SpaceChem                                                         Zachtronics
#                                                                 ...
# The Backyard                                                  Choice of Games
# Voxel Drivers                                                 Choice of Games
# A Life in Silk: The First Cumming                             Choice of Games
# Black Hornet                                                  Choice of Games
# Townsmen: A Kingdom Rebuilt                                   Choice of Games
# Name: developer, Length: 174300, dtype: object
# Processing column: tags_list
# Imputed values: game
# The Tiny Bang Story                                    ['Story Rich', 'Steampunk', 'Adventure', 'Atmo...
# World of Guns: Gun Disassembly                         ['Horror', 'First-Person', 'Historical', 'Mult...
# Microsoft Flight Simulator 40th Anniversary Edition    ['Multiplayer', 'Adventure', 'VR', 'Action Rog...
# Hacknet                                                ['Horror', 'Story Rich', 'Hacking', 'Crime', '...
# SpaceChem                                              ['Automation', 'Strategy', 'Building', 'Puzzle...
#                                                                              ...
# The Backyard                                                                         ['Indie', 'Casual']
# Voxel Drivers                                                                        ['Indie', 'Casual']
# A Life in Silk: The First Cumming                                                    ['Indie', 'Casual']
# Black Hornet                                                                         ['Indie', 'Casual']
# Townsmen: A Kingdom Rebuilt                                                          ['Indie', 'Casual']
# Name: tags_list, Length: 174300, dtype: object
# Processing column: id
# Imputed values: game
# The Tiny Bang Story                                     15120.0000
# World of Guns: Gun Disassembly                           7555.0000
# Microsoft Flight Simulator 40th Anniversary Edition    121907.2046
# Hacknet                                                 11707.0000
# SpaceChem                                                8390.0000
#                                                           ...
# The Backyard                                            71309.0000
# Voxel Drivers                                          114309.0000
# A Life in Silk: The First Cumming                       16309.0000
# Black Hornet                                            14309.0000
# Townsmen: A Kingdom Rebuilt                            115912.0000
# Name: id, Length: 174300, dtype: float64
# Processing column: age_ratings
# Imputed values: game
# The Tiny Bang Story                                                                [37971, 53144, 96817]
# World of Guns: Gun Disassembly                                                                   [60429]
# Microsoft Flight Simulator 40th Anniversary Edition                                              [60429]
# Hacknet                                                                                          [27873]
# SpaceChem                                                                                        [60429]
#                                                                              ...
# The Backyard                                                                                     [60429]
# Voxel Drivers                                                                                    [60429]
# A Life in Silk: The First Cumming                                                                [60429]
# Black Hornet                                                                                     [60429]
# Townsmen: A Kingdom Rebuilt                            [37965, 60628, 68793, 102884, 117425, 129327, ...
# Name: age_ratings, Length: 174300, dtype: object
# Processing column: first_release_date
# Imputed values: game
# The Tiny Bang Story                                    1.303430e+09
# World of Guns: Gun Disassembly                         1.400630e+09
# Microsoft Flight Simulator 40th Anniversary Edition    1.339560e+09
# Hacknet                                                1.439338e+09
# SpaceChem                                              1.293840e+09
#                                                            ...
# The Backyard                                           7.572960e+08
# Voxel Drivers                                          1.339560e+09
# A Life in Silk: The First Cumming                      1.467850e+09
# Black Hornet                                           6.941376e+08
# Townsmen: A Kingdom Rebuilt                            1.541722e+09
# Name: first_release_date, Length: 174300, dtype: float64
# Processing column: game_modes
# Imputed values: game
# The Tiny Bang Story                                    [1]
# World of Guns: Gun Disassembly                         [1]
# Microsoft Flight Simulator 40th Anniversary Edition    [1]
# Hacknet                                                [1]
# SpaceChem                                              [1]
#                                                       ...
# The Backyard                                           [1]
# Voxel Drivers                                          [1]
# A Life in Silk: The First Cumming                      [1]
# Black Hornet                                           [1]
# Townsmen: A Kingdom Rebuilt                            [1]
# Name: game_modes, Length: 174300, dtype: object
# Processing column: genres
# Imputed values: game
# The Tiny Bang Story                                    [2, 7, 9, 31, 32]
# World of Guns: Gun Disassembly                            [5, 9, 13, 32]
# Microsoft Flight Simulator 40th Anniversary Edition                 [32]
# Hacknet                                                      [9, 13, 32]
# SpaceChem                                                [9, 13, 15, 32]
#                                                              ...
# The Backyard                                                        [32]
# Voxel Drivers                                                   [10, 32]
# A Life in Silk: The First Cumming                           [12, 13, 32]
# Black Hornet                                                         [5]
# Townsmen: A Kingdom Rebuilt                                     [13, 15]
# Name: genres, Length: 174300, dtype: object
# Processing column: platforms
# Imputed values: game
# The Tiny Bang Story                                    [3, 6, 14, 34, 39, 130]
# World of Guns: Gun Disassembly                          [3, 6, 14, 34, 39, 82]
# Microsoft Flight Simulator 40th Anniversary Edition                        [6]
# Hacknet                                                             [3, 6, 14]
# SpaceChem                                                   [3, 6, 14, 34, 39]
#                                                                 ...
# The Backyard                                                               [6]
# Voxel Drivers                                                              [6]
# A Life in Silk: The First Cumming                                      [6, 14]
# Black Hornet                                                      [15, 16, 63]
# Townsmen: A Kingdom Rebuilt                                   [6, 48, 49, 130]
# Name: platforms, Length: 174300, dtype: object
# Processing column: release_dates
# Imputed values: game
# The Tiny Bang Story                                    [183886, 183887, 317300, 339037, 403342, 40334...
# World of Guns: Gun Disassembly                           [47571, 215669, 215670, 215671, 254728, 254730]
# Microsoft Flight Simulator 40th Anniversary Edition                                             [186766]
# Hacknet                                                                          [32503, 416863, 416864]
# SpaceChem                                                            [31053, 32223, 32224, 32226, 32227]
#                                                                              ...
# The Backyard                                                                                    [456767]
# Voxel Drivers                                                                                   [186766]
# A Life in Silk: The First Cumming                                                         [53289, 53290]
# Black Hornet                                                                     [40125, 505849, 505850]
# Townsmen: A Kingdom Rebuilt                                             [189308, 248694, 295890, 319978]
# Name: release_dates, Length: 174300, dtype: object
# Processing column: themes
# Imputed values: game
# The Tiny Bang Story                                    [17, 35]
# World of Guns: Gun Disassembly                          [1, 34]
# Microsoft Flight Simulator 40th Anniversary Edition         [1]
# Hacknet                                                    [43]
# SpaceChem                                                  [18]
#                                                          ...
# The Backyard                                               [34]
# Voxel Drivers                                               [1]
# A Life in Silk: The First Cumming                      [27, 42]
# Black Hornet                                            [1, 39]
# Townsmen: A Kingdom Rebuilt                            [22, 33]
# Name: themes, Length: 174300, dtype: object
# Processing column: follows
# Imputed values: game
# The Tiny Bang Story                                     7.000000
# World of Guns: Gun Disassembly                         11.297082
# Microsoft Flight Simulator 40th Anniversary Edition    11.297082
# Hacknet                                                18.000000
# SpaceChem                                               8.000000
#                                                          ...
# The Backyard                                           11.297082
# Voxel Drivers                                          11.297082
# A Life in Silk: The First Cumming                      62.000000
# Black Hornet                                           11.297082
# Townsmen: A Kingdom Rebuilt                             1.000000
# Name: follows, Length: 174300, dtype: float64
# Processing column: keywords
# Imputed values: game
# The Tiny Bang Story                                    [1140, 1158, 4134, 4484, 5262, 5657, 5704, 824...
# World of Guns: Gun Disassembly                                                               [453, 2385]
# Microsoft Flight Simulator 40th Anniversary Edition                                         [1961, 3586]
# Hacknet                                                  [103, 1423, 4466, 4520, 4586, 4609, 4882, 5379]
# SpaceChem                                              [101, 905, 948, 974, 994, 1158, 1601, 2152, 21...
#                                                                              ...
# The Backyard                                                                                [1961, 3586]
# Voxel Drivers                                                                               [1961, 3586]
# A Life in Silk: The First Cumming                                                            [847, 2147]
# Black Hornet                                                                                [1961, 3586]
# Townsmen: A Kingdom Rebuilt                                                                 [1961, 3586]
# Name: keywords, Length: 174300, dtype: object
# Processing column: collections
# Imputed values: game
# The Tiny Bang Story                                    [61]
# World of Guns: Gun Disassembly                         [61]
# Microsoft Flight Simulator 40th Anniversary Edition    [61]
# Hacknet                                                [61]
# SpaceChem                                              [61]
#                                                        ...
# The Backyard                                           [61]
# Voxel Drivers                                          [61]
# A Life in Silk: The First Cumming                      [61]
# Black Hornet                                           [61]
# Townsmen: A Kingdom Rebuilt                            [61]
# Name: collections, Length: 174300, dtype: object
# Processing column: hypes
# Imputed values: game
# The Tiny Bang Story                                    3.677878
# World of Guns: Gun Disassembly                         3.677878
# Microsoft Flight Simulator 40th Anniversary Edition    3.677878
# Hacknet                                                3.677878
# SpaceChem                                              3.677878
#                                                          ...
# The Backyard                                           3.677878
# Voxel Drivers                                          3.677878
# A Life in Silk: The First Cumming                      3.000000
# Black Hornet                                           3.677878
# Townsmen: A Kingdom Rebuilt                            2.000000
# Name: hypes, Length: 174300, dtype: float64
# Processing column: parent_game
# Imputed values: game
# The Tiny Bang Story                                    63664.510479
# World of Guns: Gun Disassembly                         63664.510479
# Microsoft Flight Simulator 40th Anniversary Edition    63664.510479
# Hacknet                                                63664.510479
# SpaceChem                                              63664.510479
#                                                            ...
# The Backyard                                           63664.510479
# Voxel Drivers                                          63664.510479
# A Life in Silk: The First Cumming                      63664.510479
# Black Hornet                                           63664.510479
# Townsmen: A Kingdom Rebuilt                            32428.000000
# Name: parent_game, Length: 174300, dtype: float64
# Processing column: rating_y
# Imputed values: game
# The Tiny Bang Story                                    72.926984
# World of Guns: Gun Disassembly                         66.706351
# Microsoft Flight Simulator 40th Anniversary Edition    66.488988
# Hacknet                                                77.907238
# SpaceChem                                              83.151954
#                                                          ...
# The Backyard                                           66.488988
# Voxel Drivers                                          40.000000
# A Life in Silk: The First Cumming                      77.373272
# Black Hornet                                           66.488988
# Townsmen: A Kingdom Rebuilt                            50.000000
# Name: rating_y, Length: 174300, dtype: float64
# Processing column: rating_count
# Imputed values: game
# The Tiny Bang Story                                    27.000000
# World of Guns: Gun Disassembly                          8.000000
# Microsoft Flight Simulator 40th Anniversary Edition    22.929464
# Hacknet                                                31.000000
# SpaceChem                                              25.000000
#                                                          ...
# The Backyard                                           22.929464
# Voxel Drivers                                           0.000000
# A Life in Silk: The First Cumming                      13.000000
# Black Hornet                                           22.929464
# Townsmen: A Kingdom Rebuilt                             1.000000
# Name: rating_count, Length: 174300, dtype: float64
# Processing column: total_rating
# Imputed values: game
# The Tiny Bang Story                                    71.463492
# World of Guns: Gun Disassembly                         66.706351
# Microsoft Flight Simulator 40th Anniversary Edition    66.403659
# Hacknet                                                82.953619
# SpaceChem                                              83.151954
#                                                          ...
# The Backyard                                           66.403659
# Voxel Drivers                                          40.000000
# A Life in Silk: The First Cumming                      77.373272
# Black Hornet                                           66.403659
# Townsmen: A Kingdom Rebuilt                            50.000000
# Name: total_rating, Length: 174300, dtype: float64
# Processing column: total_rating_count
# Imputed values: game
# The Tiny Bang Story                                    28.000000
# World of Guns: Gun Disassembly                          8.000000
# Microsoft Flight Simulator 40th Anniversary Edition    21.060525
# Hacknet                                                32.000000
# SpaceChem                                              25.000000
#                                                          ...
# The Backyard                                           21.060525
# Voxel Drivers                                           0.000000
# A Life in Silk: The First Cumming                      13.000000
# Black Hornet                                           21.060525
# Townsmen: A Kingdom Rebuilt                             1.000000
# Name: total_rating_count, Length: 174300, dtype: float64
# Processing column: aggregated_rating
# Imputed values: game
# The Tiny Bang Story                                    70.000000
# World of Guns: Gun Disassembly                         69.097603
# Microsoft Flight Simulator 40th Anniversary Edition    69.097603
# Hacknet                                                88.000000
# SpaceChem                                              69.097603
#                                                          ...
# The Backyard                                           69.097603
# Voxel Drivers                                          69.097603
# A Life in Silk: The First Cumming                      69.097603
# Black Hornet                                           69.097603
# Townsmen: A Kingdom Rebuilt                            69.097603
# Name: aggregated_rating, Length: 174300, dtype: float64
# Processing column: aggregated_rating_count
# Imputed values: game
# The Tiny Bang Story                                    1.00000
# World of Guns: Gun Disassembly                         3.61543
# Microsoft Flight Simulator 40th Anniversary Edition    3.61543
# Hacknet                                                1.00000
# SpaceChem                                              3.61543
#                                                         ...
# The Backyard                                           3.61543
# Voxel Drivers                                          3.61543
# A Life in Silk: The First Cumming                      3.61543
# Black Hornet                                           3.61543
# Townsmen: A Kingdom Rebuilt                            3.61543
# Name: aggregated_rating_count, Length: 174300, dtype: float64
# Processing column: storyline
# Imputed values: game
# The Tiny Bang Story                                    Life on Tiny Planet was calm and carefree unti...
# World of Guns: Gun Disassembly                         World of Guns: Gun Disassembly lets you delve ...
# Microsoft Flight Simulator 40th Anniversary Edition    Alone is a puzzle/brain game which both the ye...
# Hacknet                                                Bit, a hacker responsible for creating the mos...
# SpaceChem                                              SpaceChem is a puzzle game about chemical engi...
#                                                                              ...
# The Backyard                                           The Backyard is an educational game for toddle...
# Voxel Drivers                                          Alone is a puzzle/brain game which both the ye...
# A Life in Silk: The First Cumming                      A Life in Silk is a highly-interactive visual-...
# Black Hornet                                           You pilot the Black Hornet, an advanced stealt...
# Townsmen: A Kingdom Rebuilt                            Townsmen – A Kingdom Rebuilt hands the crown t...
# Name: storyline, Length: 174300, dtype: object
# Processing column: franchise
# Imputed values: game
# The Tiny Bang Story                                    132.287129
# World of Guns: Gun Disassembly                         132.287129
# Microsoft Flight Simulator 40th Anniversary Edition    132.287129
# Hacknet                                                132.287129
# SpaceChem                                              132.287129
#                                                           ...
# The Backyard                                           132.287129
# Voxel Drivers                                          132.287129
# A Life in Silk: The First Cumming                      132.287129
# Black Hornet                                           132.287129
# Townsmen: A Kingdom Rebuilt                            132.287129
# Name: franchise, Length: 174300, dtype: float64

# %%
twitch_zaggle_merged_df['year'] = twitch_zaggle_merged_df['year'].astype(int)
twitch_zaggle_merged_df
# Out:
#                                                     year  metacritic_rating  \
# game
# The Tiny Bang Story                                 2011          63.000000
# World of Guns: Gun Disassembly                      2014          72.618027
# Microsoft Flight Simulator 40th Anniversary Edi...  2020          91.000000
# Hacknet                                             2015          82.000000
# SpaceChem                                           2011          84.000000
# ...                                                  ...                ...
# The Backyard                                        1993          72.618027
# Voxel Drivers                                       2015          72.618027
# A Life in Silk: The First Cumming                   2015          72.618027
# Black Hornet                                        1991          72.618027
# Townsmen: A Kingdom Rebuilt                         2015          72.618027
#
#                                                     reviewer_rating  \
# game
# The Tiny Bang Story                                        8.000000
# World of Guns: Gun Disassembly                             8.000000
# Microsoft Flight Simulator 40th Anniversary Edi...         6.000000
# Hacknet                                                    8.000000
# SpaceChem                                                  8.000000
# ...                                                             ...
# The Backyard                                               6.368626
# Voxel Drivers                                              6.368626
# A Life in Silk: The First Cumming                          6.368626
# Black Hornet                                               6.368626
# Townsmen: A Kingdom Rebuilt                                6.368626
#
#                                                     positivity_ratio  \
# game
# The Tiny Bang Story                                         7.073879
# World of Guns: Gun Disassembly                              5.208940
# Microsoft Flight Simulator 40th Anniversary Edi...          3.581082
# Hacknet                                                    14.548520
# SpaceChem                                                  11.440415
# ...                                                              ...
# The Backyard                                                5.056642
# Voxel Drivers                                               5.056642
# A Life in Silk: The First Cumming                           5.056642
# Black Hornet                                                5.056642
# Townsmen: A Kingdom Rebuilt                                 5.056642
#
#                                                      rating_x primary_genre  \
# game
# The Tiny Bang Story                                 84.850000     Adventure
# World of Guns: Gun Disassembly                      82.090000          Free
# Microsoft Flight Simulator 40th Anniversary Edi...  64.847944         Indie
# Hacknet                                             91.410000    Simulation
# SpaceChem                                           88.720000    Simulation
# ...                                                       ...           ...
# The Backyard                                        64.847944         Indie
# Voxel Drivers                                       64.847944         Indie
# A Life in Silk: The First Cumming                   64.847944         Indie
# Black Hornet                                        64.847944         Indie
# Townsmen: A Kingdom Rebuilt                         64.847944         Indie
#
#                                                                                          store_genres  \
# game
# The Tiny Bang Story                                                  ['Adventure', 'Casual', 'Indie']
# World of Guns: Gun Disassembly                      ['Action', 'Casual', 'Free', 'Indie', 'Simulat...
# Microsoft Flight Simulator 40th Anniversary Edi...  [Simulation,  Flight,  Realistic,  Open World,...
# Hacknet                                                                       ['Indie', 'Simulation']
# SpaceChem                                                                     ['Indie', 'Simulation']
# ...                                                                                               ...
# The Backyard                                                                                   Action
# Voxel Drivers                                                                                  Action
# A Life in Silk: The First Cumming                                                              Action
# Black Hornet                                                                                  Shooter
# Townsmen: A Kingdom Rebuilt                                                                  Strategy
#
#                                                                publisher  \
# game
# The Tiny Bang Story                                        Colibri Games
# World of Guns: Gun Disassembly                        Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...                  Sega
# Hacknet                                                 Fellow Traveller
# SpaceChem                                                    Zachtronics
# ...                                                                  ...
# The Backyard                                         Broderbund Software
# Voxel Drivers                                                       Sega
# A Life in Silk: The First Cumming                                   Sega
# Black Hornet                                        Hi-Tec Software Ltd.
# Townsmen: A Kingdom Rebuilt                                   HandyGames
#
#                                                                  developer  \
# game
# The Tiny Bang Story                                          Colibri Games
# World of Guns: Gun Disassembly                          Noble Empire Corp.
# Microsoft Flight Simulator 40th Anniversary Edi...         Choice of Games
# Hacknet                                             Team Fractal Alligator
# SpaceChem                                                      Zachtronics
# ...                                                                    ...
# The Backyard                                               Choice of Games
# Voxel Drivers                                              Choice of Games
# A Life in Silk: The First Cumming                          Choice of Games
# Black Hornet                                               Choice of Games
# Townsmen: A Kingdom Rebuilt                                Choice of Games
#
#                                                                                             tags_list  \
# game
# The Tiny Bang Story                                 ['Story Rich', 'Steampunk', 'Adventure', 'Atmo...
# World of Guns: Gun Disassembly                      ['Horror', 'First-Person', 'Historical', 'Mult...
# Microsoft Flight Simulator 40th Anniversary Edi...  ['Multiplayer', 'Adventure', 'VR', 'Action Rog...
# Hacknet                                             ['Horror', 'Story Rich', 'Hacking', 'Crime', '...
# SpaceChem                                           ['Automation', 'Strategy', 'Building', 'Puzzle...
# ...                                                                                               ...
# The Backyard                                                                      ['Indie', 'Casual']
# Voxel Drivers                                                                     ['Indie', 'Casual']
# A Life in Silk: The First Cumming                                                 ['Indie', 'Casual']
# Black Hornet                                                                      ['Indie', 'Casual']
# Townsmen: A Kingdom Rebuilt                                                       ['Indie', 'Casual']
#
#                                                     ...     hypes  \
# game                                                ...
# The Tiny Bang Story                                 ...  3.677878
# World of Guns: Gun Disassembly                      ...  3.677878
# Microsoft Flight Simulator 40th Anniversary Edi...  ...  3.677878
# Hacknet                                             ...  3.677878
# SpaceChem                                           ...  3.677878
# ...                                                 ...       ...
# The Backyard                                        ...  3.677878
# Voxel Drivers                                       ...  3.677878
# A Life in Silk: The First Cumming                   ...  3.000000
# Black Hornet                                        ...  3.677878
# Townsmen: A Kingdom Rebuilt                         ...  2.000000
#
#                                                      parent_game   rating_y  \
# game
# The Tiny Bang Story                                 63664.510479  72.926984
# World of Guns: Gun Disassembly                      63664.510479  66.706351
# Microsoft Flight Simulator 40th Anniversary Edi...  63664.510479  66.488988
# Hacknet                                             63664.510479  77.907238
# SpaceChem                                           63664.510479  83.151954
# ...                                                          ...        ...
# The Backyard                                        63664.510479  66.488988
# Voxel Drivers                                       63664.510479  40.000000
# A Life in Silk: The First Cumming                   63664.510479  77.373272
# Black Hornet                                        63664.510479  66.488988
# Townsmen: A Kingdom Rebuilt                         32428.000000  50.000000
#
#                                                    rating_count total_rating  \
# game
# The Tiny Bang Story                                   27.000000    71.463492
# World of Guns: Gun Disassembly                         8.000000    66.706351
# Microsoft Flight Simulator 40th Anniversary Edi...    22.929464    66.403659
# Hacknet                                               31.000000    82.953619
# SpaceChem                                             25.000000    83.151954
# ...                                                         ...          ...
# The Backyard                                          22.929464    66.403659
# Voxel Drivers                                          0.000000    40.000000
# A Life in Silk: The First Cumming                     13.000000    77.373272
# Black Hornet                                          22.929464    66.403659
# Townsmen: A Kingdom Rebuilt                            1.000000    50.000000
#
#                                                    total_rating_count  \
# game
# The Tiny Bang Story                                         28.000000
# World of Guns: Gun Disassembly                               8.000000
# Microsoft Flight Simulator 40th Anniversary Edi...          21.060525
# Hacknet                                                     32.000000
# SpaceChem                                                   25.000000
# ...                                                               ...
# The Backyard                                                21.060525
# Voxel Drivers                                                0.000000
# A Life in Silk: The First Cumming                           13.000000
# Black Hornet                                                21.060525
# Townsmen: A Kingdom Rebuilt                                  1.000000
#
#                                                    aggregated_rating  \
# game
# The Tiny Bang Story                                        70.000000
# World of Guns: Gun Disassembly                             69.097603
# Microsoft Flight Simulator 40th Anniversary Edi...         69.097603
# Hacknet                                                    88.000000
# SpaceChem                                                  69.097603
# ...                                                              ...
# The Backyard                                               69.097603
# Voxel Drivers                                              69.097603
# A Life in Silk: The First Cumming                          69.097603
# Black Hornet                                               69.097603
# Townsmen: A Kingdom Rebuilt                                69.097603
#
#                                                    aggregated_rating_count  \
# game
# The Tiny Bang Story                                                1.00000
# World of Guns: Gun Disassembly                                     3.61543
# Microsoft Flight Simulator 40th Anniversary Edi...                 3.61543
# Hacknet                                                            1.00000
# SpaceChem                                                          3.61543
# ...                                                                    ...
# The Backyard                                                       3.61543
# Voxel Drivers                                                      3.61543
# A Life in Silk: The First Cumming                                  3.61543
# Black Hornet                                                       3.61543
# Townsmen: A Kingdom Rebuilt                                        3.61543
#
#                                                                                             storyline  \
# game
# The Tiny Bang Story                                 Life on Tiny Planet was calm and carefree unti...
# World of Guns: Gun Disassembly                      World of Guns: Gun Disassembly lets you delve ...
# Microsoft Flight Simulator 40th Anniversary Edi...  Alone is a puzzle/brain game which both the ye...
# Hacknet                                             Bit, a hacker responsible for creating the mos...
# SpaceChem                                           SpaceChem is a puzzle game about chemical engi...
# ...                                                                                               ...
# The Backyard                                        The Backyard is an educational game for toddle...
# Voxel Drivers                                       Alone is a puzzle/brain game which both the ye...
# A Life in Silk: The First Cumming                   A Life in Silk is a highly-interactive visual-...
# Black Hornet                                        You pilot the Black Hornet, an advanced stealt...
# Townsmen: A Kingdom Rebuilt                         Townsmen – A Kingdom Rebuilt hands the crown t...
#
#                                                      franchise
# game
# The Tiny Bang Story                                 132.287129
# World of Guns: Gun Disassembly                      132.287129
# Microsoft Flight Simulator 40th Anniversary Edi...  132.287129
# Hacknet                                             132.287129
# SpaceChem                                           132.287129
# ...                                                        ...
# The Backyard                                        132.287129
# Voxel Drivers                                       132.287129
# A Life in Silk: The First Cumming                   132.287129
# Black Hornet                                        132.287129
# Townsmen: A Kingdom Rebuilt                         132.287129
#
# [174300 rows x 31 columns]

# %%
# Generate summary statistics
twitch_zaggle_merged_df.describe()
# Out:
#                 year  metacritic_rating  reviewer_rating  positivity_ratio  \
# count  174300.000000      174300.000000    174300.000000     174300.000000
# mean     2015.186994          72.618027         6.368626          5.056642
# std        24.339531           1.696774         0.732539          5.380107
# min        19.000000          20.000000         1.000000          0.020000
# 25%      2015.000000          72.618027         6.368626          3.846154
# 50%      2015.000000          72.618027         6.368626          5.056642
# 75%      2020.000000          72.618027         6.368626          5.056642
# max      2023.000000          97.000000         9.000000        591.000000
#
#             rating_x             id  first_release_date        follows  \
# count  174300.000000  174300.000000        1.743000e+05  174300.000000
# mean       64.847944  121907.204600        1.339560e+09      11.297082
# std         9.338503   73854.831287        2.857461e+08      16.792477
# min        15.090000       1.000000       -6.107616e+08       1.000000
# 25%        64.847944   55578.500000        1.339560e+09      11.297082
# 50%        64.847944  121907.204600        1.339560e+09      11.297082
# 75%        64.847944  170857.250000        1.541462e+09      11.297082
# max        97.540000  277234.000000        1.894406e+09    1798.000000
#
#                hypes    parent_game       rating_y   rating_count  \
# count  174300.000000  174300.000000  174300.000000  174300.000000
# mean        3.677878   63664.510479      66.488988      22.929464
# std         4.172659   31004.493830       5.990097      46.525604
# min         1.000000       1.000000      10.015294       0.000000
# 25%         3.677878   63664.510479      66.488988      22.929464
# 50%         3.677878   63664.510479      66.488988      22.929464
# 75%         3.677878   63664.510479      66.488988      22.929464
# max      1038.000000  276958.000000     100.000000    4098.000000
#
#         total_rating  total_rating_count  aggregated_rating  \
# count  174300.000000       174300.000000      174300.000000
# mean       66.403659           21.060525          69.097603
# std         6.655030           47.282102           4.782090
# min         0.000000            0.000000           0.000000
# 25%        66.403659           21.060525          69.097603
# 50%        66.403659           21.060525          69.097603
# 75%        66.403659           21.060525          69.097603
# max       100.000000         4135.000000         100.000000
#
#        aggregated_rating_count      franchise
# count            174300.000000  174300.000000
# mean                  3.615430     132.287129
# std                   1.199846      11.377643
# min                   0.000000       1.000000
# 25%                   3.615430     132.287129
# 50%                   3.615430     132.287129
# 75%                   3.615430     132.287129
# max                  59.000000     444.000000

# %%
twitch_zaggle_merged_df.shape
# Out:
# (174300, 31)

# %%
Prepare the Data

# %%
twitch_zaggle_merged_df.columns

# %%
# # Identify non-numeric columns
# non_numeric_columns = ['primary_genre', 'store_genres', 'publisher', 'developer', 'tags_list',
#                        'first_release_date', 'game_modes', 'genres', 'platforms', 'release_dates',
#                        'themes', 'parent_game', 'storyline', 'franchise']

# # Select only numeric columns for scaling
# numeric_columns = [col for col in twitch_zaggle_merged_df.columns if col not in non_numeric_columns]

# # Use StandardScaler on numeric columns
# pixi_scaled = StandardScaler().fit_transform(twitch_zaggle_merged_df[numeric_columns])

# pixi_scaled_df = pd.DataFrame(pixi_scaled, columns=numeric_columns)


# Identify non-numeric columns
non_numeric_columns = ['primary_genre', 'store_genres', 'publisher', 'developer', 'tags_list',
                       'first_release_date', 'game_modes', 'genres', 'platforms', 'release_dates',
                       'themes', 'parent_game', 'storyline', 'franchise']

# Select only numeric columns for scaling
numeric_columns = [col for col in twitch_zaggle_merged_df.columns if col not in non_numeric_columns]

# Use StandardScaler on numeric columns
pixi_scaled = StandardScaler().fit_transform(twitch_zaggle_merged_df[numeric_columns])

pixi_scaled_df = pd.DataFrame(pixi_scaled, columns=numeric_columns)

# %%
twitch_zaggle_merged_df[numeric_columns].dtypes

# %%
# Define the LabelEncoder
label_encoder = LabelEncoder()

# Function to handle different data types in a column
def preprocess_column(column):
    # Convert NaN and lists to a placeholder string
    column = column.apply(lambda x: str(x) if pd.notnull(x) and not isinstance(x, (int, float)) else x)

    # Use LabelEncoder
    return label_encoder.fit_transform(column)

# Apply the preprocessing to the specified columns
twitch_zaggle_merged_df['age_ratings'] = preprocess_column(twitch_zaggle_merged_df['age_ratings'])
twitch_zaggle_merged_df['keywords'] = preprocess_column(twitch_zaggle_merged_df['keywords'])
twitch_zaggle_merged_df['collections'] = preprocess_column(twitch_zaggle_merged_df['collections'])


# label_encoder = LabelEncoder()

# twitch_zaggle_merged_df['age_ratings'] = label_encoder.fit_transform(twitch_zaggle_merged_df['age_ratings'])
# twitch_zaggle_merged_df['keywords'] = label_encoder.fit_transform(twitch_zaggle_merged_df['keywords'])
# twitch_zaggle_merged_df['collections'] = label_encoder.fit_transform(twitch_zaggle_merged_df['collections'])

# %%
pixi_scaled_df

# %%
# Create a DataFrame with the scaled data
#did not include id
pixi_scaled_df = pd.DataFrame(pixi_scaled_df, 
                                columns=['year', 'metacritic_rating', 'reviewer_rating', 'positivity_ratio',
                                         'rating_x', 'age_ratings', 'follows','keywords', 'collections', 
                                         'hypes', 'rating_y', 'rating_count', 'total_rating', 
                                         'total_rating_count','aggregated_rating'])
pixi_scaled_df.head()

# %%
# Copy the crypto names from the original data
pixi_scaled_df['game'] = twitch_zaggle_merged_df.index

# Set the coinid column as index
pixi_scaled_df = pixi_scaled_df.set_index('game')

# Display sample data
pixi_scaled_df.head()

# %%
Finding best value for k using original data

# %%
# Create a list with the number of k-values from 1 to 50
#used 50 in this case due to volume of data and genre
# Create an empty list to store the inertia values
# M19, D3, A3
inertia = []
k = list(range(1, 50))

# %%
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
# M19, D3, A3
for i in k:
    k_model = KMeans(n_clusters=i, random_state=0)
    k_model.fit(pixi_scaled_df)
    inertia.append(k_model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

df_elbow.head()

# %%
Cluster Games with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
#M19, D3, A2
model = KMeans(n_clusters=11, random_state=1)

# %%
# Fit the K-Means model using the PCA data
model.fit(pixi_scaled_df)

# %%
# Predict the clusters to group the Games using the PCA data
k11 = model.predict(pixi_scaled_df)

# Print the resulting array of cluster values.
k11

# %%
# Create a copy of the DataFrame
pixi_scaled_df_predictions = pixi_scaled_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
pixi_scaled_df_predictions['Predicted'] = k11

# Display sample data
pixi_scaled_df_predictions.tail()

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="total_rating"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
prediction_plot = pixi_scaled_df_predictions.hvplot.scatter(
    x="hypes",
    y="total_rating",
    by="Predicted",
    hover_cols=['game']
)

prediction_plot

# %%
Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=11`.
#M19, D3, A2
pca = PCA(n_components=11)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
pixi_pca = pca.fit_transform(pixi_scaled_df)

# View the first five rows of the DataFrame. 
pixi_pca[:5]

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
pca.explained_variance_ratio_

# %%
total_variance = np.sum(pca.explained_variance_ratio_)
total_variance

# %%
print("Explained variance ratio of each component:", pca.explained_variance_ratio_)

# %%
#Total explained variance is 96%?

# %%
# Create a new DataFrame with the PCA data.
pixi_pca = pd.DataFrame(
    pixi_pca,
    columns=["PCA1", "PCA2", "PCA3",'PCA4','PCA5','PCA6','PCA7','PCA8','PCA9','PCA10','PCA11'])

# Copy the games from the original data
pixi_pca['games'] = pixi_scaled_df.index

# Set the games column as index
pixi_pca = pixi_pca.set_index('games')

# Display sample data
pixi_pca.head()

# %%
### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
# Create an empty list to store the inertia values
#M19, D3, A2
inertia_pca = []
k_pca = list(range(1, 30))

# %%
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k_pca:
    k_model = KMeans(n_clusters=i, random_state=1)
    k_model.fit(pixi_pca)
    inertia_pca.append(k_model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
pca_elbow = {'k_pca': k_pca, 'inertia_pca': inertia_pca}

# Create a DataFrame with the data to plot the Elbow curve
pca_elbow_df = pd.DataFrame(pca_elbow)
pca_elbow_df.head()

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
pca_elbow_plot = pca_elbow_df.hvplot.line(
    x="k_pca", 
    y="inertia_pca", 
    title="Elbow Curve", 
    xticks=k
)

pca_elbow_plot

# %%
## would k be 5 or 7? or a different one?

# %%
#Cluster Games with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
#M19, D3, A2
model = KMeans(n_clusters=7, random_state=1)

# %%
# Fit the K-Means model using the PCA data
model.fit(pixi_pca)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
k7 = model.predict(pixi_pca)

# Print the resulting array of cluster values.
k7

# %%
# Create a copy of the DataFrame with the PCA data
k_7_pca_df = pixi_pca.copy()

# Add a new column to the DataFrame with the predicted clusters
k_7_pca_df['Predicted_Cluster'] = k7

# Display sample data
k_7_pca_df.head()

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
k_7_plot = k_7_pca_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="Predicted_Cluster",
    hover_cols = ['game']
)

k_7_plot
